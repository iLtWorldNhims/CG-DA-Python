# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
lst = ['Kế toán','Kinh doanh','Tiếp thị']
df = pd.DataFrame(lst)
df
# Out:
#             0
# 0     Kế toán
# 1  Kinh doanh
# 2    Tiếp thị

# %%
tuples = [('Kế toán',2000),('Kinh doanh',2100),('Tiếp thị',1900)]
df = pd.DataFrame(tuples)
df
# Out:
#             0     1
# 0     Kế toán  2000
# 1  Kinh doanh  2100
# 2    Tiếp thị  1900

# %%
dic = {'Nghề':['Kế toán','Kinh doanh','Tiếp thị'],
      'Lương':[2000,2100,1900]}
df = pd.DataFrame(dic)
df
# Out:
#          Nghề  Lương
# 0     Kế toán   2000
# 1  Kinh doanh   2100
# 2    Tiếp thị   1900

# %%
arr = np.array([51,65,48,59,68])
seri2 = pd.Series(arr)
seri2
# Out:
# 0    51
# 1    65
# 2    48
# 3    59
# 4    68
# dtype: int32

# %%
data = pd.read_csv('FoodPrice_in_Turkey.csv',
                  header = 0, encoding = 'ISO-8859-1')
print('*'*20,'Nhập dữ liệu thành công','*'*20)
display(data)
data.info()
# Out:
# ******************** Nhập dữ liệu thành công ********************
#                  Place  ProductId              ProductName  UmId UmName  \
# 0     National Average         52            Rice - Retail     5     KG
# 1     National Average         52            Rice - Retail     5     KG
# 2     National Average         52            Rice - Retail     5     KG
# 3     National Average         52            Rice - Retail     5     KG
# 4     National Average         52            Rice - Retail     5     KG
# ...                ...        ...                      ...   ...    ...
# 7376             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7377             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7378             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7379             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7380             Izmir        502  Cocoa (powder) - Retail     5     KG
#
#       Month  Year    Price
# 0         5  2013   4.4920
# 1         6  2013   4.5786
# 2        11  2013   4.7865
# 3        12  2013   5.1337
# 4         1  2014   5.5099
# ...     ...   ...      ...
# 7376      8  2019  47.9040
# 7377      9  2019  49.1176
# 7378     10  2019  50.8347
# 7379     11  2019  51.7985
# 7380     12  2019  51.6071
#
# [7381 rows x 8 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7381 entries, 0 to 7380
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Place        7381 non-null   object
#  1   ProductId    7381 non-null   int64
#  2   ProductName  7381 non-null   object
#  3   UmId         7381 non-null   int64
#  4   UmName       7381 non-null   object
#  5   Month        7381 non-null   int64
#  6   Year         7381 non-null   int64
#  7   Price        7381 non-null   float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 461.4+ KB

# %%
data.columns
# Out:
# Index(['Place', 'ProductId', 'ProductName', 'UmId', 'UmName', 'Month', 'Year',
#        'Price'],
#       dtype='object')

# %%
# Việt hóa tên các cột
# Đổi tên chỉ 1 cột xác định
# data.rename(columns = {'Place':'Địa điểm'}, inplace=True)

# Đổi tên chỉ 1 vài cột xác định
# data.rename(columns = {'ProductId':'Mã sản phẩm', 'ProductName':'Tên sản phẩm'}, inplace=True)
# data.rename(columns = {'UmId':'Số lượng', 'UmName':'Tên đơn vị'}, inplace=False) #Bảng data không thay đổi

# Đổi tên toàn bộ các cột (Yêu cầu liệt kê đầy đủ tên cột mới và theo đúng thứ tự)
data.columns = ['Địa điểm', 'Mã SP', 'Tên SP', 'Đơn vị', 'Tên đơn vị', 'Tháng', 'Năm', 'Giá'] #Phải đủ số lượng tên các cột

data
# Out:
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0     National Average     52            Rice - Retail       5         KG
# 1     National Average     52            Rice - Retail       5         KG
# 2     National Average     52            Rice - Retail       5         KG
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7376             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7377             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7378             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7379             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
#
#       Tháng   Năm      Giá
# 0         5  2013   4.4920
# 1         6  2013   4.5786
# 2        11  2013   4.7865
# 3        12  2013   5.1337
# 4         1  2014   5.5099
# ...     ...   ...      ...
# 7376      8  2019  47.9040
# 7377      9  2019  49.1176
# 7378     10  2019  50.8347
# 7379     11  2019  51.7985
# 7380     12  2019  51.6071
#
# [7381 rows x 8 columns]

# %%
data['Tên cột mới'] = np.NaN
display(data)
# Out:
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0     National Average     52            Rice - Retail       5         KG
# 1     National Average     52            Rice - Retail       5         KG
# 2     National Average     52            Rice - Retail       5         KG
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7376             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7377             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7378             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7379             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
#
#       Tháng   Năm      Giá  Tên cột mới
# 0         5  2013   4.4920          NaN
# 1         6  2013   4.5786          NaN
# 2        11  2013   4.7865          NaN
# 3        12  2013   5.1337          NaN
# 4         1  2014   5.5099          NaN
# ...     ...   ...      ...          ...
# 7376      8  2019  47.9040          NaN
# 7377      9  2019  49.1176          NaN
# 7378     10  2019  50.8347          NaN
# 7379     11  2019  51.7985          NaN
# 7380     12  2019  51.6071          NaN
#
# [7381 rows x 9 columns]

# %%
data.insert(8, 'Chiết khấu (%)', 20)
display(data)
# data.info()
# Out:
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0     National Average     52            Rice - Retail       5         KG
# 1     National Average     52            Rice - Retail       5         KG
# 2     National Average     52            Rice - Retail       5         KG
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7376             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7377             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7378             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7379             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
#
#       Tháng   Năm      Giá  Chiết khấu (%)  Tên cột mới
# 0         5  2013   4.4920              20          NaN
# 1         6  2013   4.5786              20          NaN
# 2        11  2013   4.7865              20          NaN
# 3        12  2013   5.1337              20          NaN
# 4         1  2014   5.5099              20          NaN
# ...     ...   ...      ...             ...          ...
# 7376      8  2019  47.9040              20          NaN
# 7377      9  2019  49.1176              20          NaN
# 7378     10  2019  50.8347              20          NaN
# 7379     11  2019  51.7985              20          NaN
# 7380     12  2019  51.6071              20          NaN
#
# [7381 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7381 entries, 0 to 7380
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Địa điểm        7381 non-null   object
#  1   Mã SP           7381 non-null   int64
#  2   Tên SP          7381 non-null   object
#  3   Đơn vị          7381 non-null   int64
#  4   Tên đơn vị      7381 non-null   object
#  5   Tháng           7381 non-null   int64
#  6   Năm             7381 non-null   int64
#  7   Giá             7381 non-null   float64
#  8   Chiết khấu (%)  7381 non-null   int64
#  9   Tên cột mới     0 non-null      float64
# dtypes: float64(2), int64(5), object(3)
# memory usage: 576.8+ KB

# %%
data.pop('Chiết khấu (%)')
# Out:
# 0       20
# 1       20
# 2       20
# 3       20
# 4       20
#         ..
# 7376    20
# 7377    20
# 7378    20
# 7379    20
# 7380    20
# Name: Chiết khấu (%), Length: 7381, dtype: int64

# %%
data
# Out:
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0     National Average     52            Rice - Retail       5         KG
# 1     National Average     52            Rice - Retail       5         KG
# 2     National Average     52            Rice - Retail       5         KG
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7376             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7377             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7378             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7379             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
#
#       Tháng   Năm      Giá  Tên cột mới
# 0         5  2013   4.4920          NaN
# 1         6  2013   4.5786          NaN
# 2        11  2013   4.7865          NaN
# 3        12  2013   5.1337          NaN
# 4         1  2014   5.5099          NaN
# ...     ...   ...      ...          ...
# 7376      8  2019  47.9040          NaN
# 7377      9  2019  49.1176          NaN
# 7378     10  2019  50.8347          NaN
# 7379     11  2019  51.7985          NaN
# 7380     12  2019  51.6071          NaN
#
# [7381 rows x 9 columns]

# %%
print(data)
# Out:
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0     National Average     52            Rice - Retail       5         KG
# 1     National Average     52            Rice - Retail       5         KG
# 2     National Average     52            Rice - Retail       5         KG
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7376             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7377             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7378             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7379             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
#
#       Tháng   Năm      Giá  Chiết khấu (%)  Tên cột mới
# 0         5  2013   4.4920              20          NaN
# 1         6  2013   4.5786              20          NaN
# 2        11  2013   4.7865              20          NaN
# 3        12  2013   5.1337              20          NaN
# 4         1  2014   5.5099              20          NaN
# ...     ...   ...      ...             ...          ...
# 7376      8  2019  47.9040              20          NaN
# 7377      9  2019  49.1176              20          NaN
# 7378     10  2019  50.8347              20          NaN
# 7379     11  2019  51.7985              20          NaN
# 7380     12  2019  51.6071              20          NaN
#
# [7381 rows x 10 columns]

# %%
display(data)
# Out:
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0     National Average     52            Rice - Retail       5         KG
# 1     National Average     52            Rice - Retail       5         KG
# 2     National Average     52            Rice - Retail       5         KG
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7376             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7377             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7378             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7379             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
#
#       Tháng   Năm      Giá  Chiết khấu (%)  Tên cột mới
# 0         5  2013   4.4920              20          NaN
# 1         6  2013   4.5786              20          NaN
# 2        11  2013   4.7865              20          NaN
# 3        12  2013   5.1337              20          NaN
# 4         1  2014   5.5099              20          NaN
# ...     ...   ...      ...             ...          ...
# 7376      8  2019  47.9040              20          NaN
# 7377      9  2019  49.1176              20          NaN
# 7378     10  2019  50.8347              20          NaN
# 7379     11  2019  51.7985              20          NaN
# 7380     12  2019  51.6071              20          NaN
#
# [7381 rows x 10 columns]

# %%
data.insert(7, 'Số lượng', 50)
data
# Out:
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0     National Average     52            Rice - Retail       5         KG
# 1     National Average     52            Rice - Retail       5         KG
# 2     National Average     52            Rice - Retail       5         KG
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7376             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7377             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7378             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7379             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
#
#       Tháng   Năm  Số lượng      Giá  Chiết khấu (%)  Tên cột mới
# 0         5  2013        50   4.4920              20          NaN
# 1         6  2013        50   4.5786              20          NaN
# 2        11  2013        50   4.7865              20          NaN
# 3        12  2013        50   5.1337              20          NaN
# 4         1  2014        50   5.5099              20          NaN
# ...     ...   ...       ...      ...             ...          ...
# 7376      8  2019        50  47.9040              20          NaN
# 7377      9  2019        50  49.1176              20          NaN
# 7378     10  2019        50  50.8347              20          NaN
# 7379     11  2019        50  51.7985              20          NaN
# 7380     12  2019        50  51.6071              20          NaN
#
# [7381 rows x 11 columns]

# %%
data.rename(columns = {'Tên cột mới': 'Tổng'}, inplace = True)
data['Tổng'] = data['Giá'] * data['Số lượng'] * (100 - data['Chiết khấu (%)'])/100
data
# Out:
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0     National Average     52            Rice - Retail       5         KG
# 1     National Average     52            Rice - Retail       5         KG
# 2     National Average     52            Rice - Retail       5         KG
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7376             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7377             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7378             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7379             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
#
#       Tháng   Năm  Số lượng      Giá  Chiết khấu (%)      Tổng
# 0         5  2013        50   4.4920              20   179.680
# 1         6  2013        50   4.5786              20   183.144
# 2        11  2013        50   4.7865              20   191.460
# 3        12  2013        50   5.1337              20   205.348
# 4         1  2014        50   5.5099              20   220.396
# ...     ...   ...       ...      ...             ...       ...
# 7376      8  2019        50  47.9040              20  1916.160
# 7377      9  2019        50  49.1176              20  1964.704
# 7378     10  2019        50  50.8347              20  2033.388
# 7379     11  2019        50  51.7985              20  2071.940
# 7380     12  2019        50  51.6071              20  2064.284
#
# [7381 rows x 11 columns]

# %%
data.loc[data.shape[0]] = ['Sài Gòn', 3000, 'Dưa hấu', 5, 'KG', 10, 2022, 50, 50.000, 10, np.NaN]
display(data)
# Out:
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0     National Average     52            Rice - Retail       5         KG
# 1     National Average     52            Rice - Retail       5         KG
# 2     National Average     52            Rice - Retail       5         KG
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7377             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7378             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7379             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7381           Sài Gòn   3000                  Dưa hấu       5         KG
#
#       Tháng   Năm  Số lượng      Giá  Chiết khấu (%)      Tổng
# 0         5  2013        50   4.4920              20   179.680
# 1         6  2013        50   4.5786              20   183.144
# 2        11  2013        50   4.7865              20   191.460
# 3        12  2013        50   5.1337              20   205.348
# 4         1  2014        50   5.5099              20   220.396
# ...     ...   ...       ...      ...             ...       ...
# 7377      9  2019        50  49.1176              20  1964.704
# 7378     10  2019        50  50.8347              20  2033.388
# 7379     11  2019        50  51.7985              20  2071.940
# 7380     12  2019        50  51.6071              20  2064.284
# 7381     10  2022        50  50.0000              10       NaN
#
# [7382 rows x 11 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7382 entries, 0 to 7381
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Địa điểm        7382 non-null   object
#  1   Mã SP           7382 non-null   int64
#  2   Tên SP          7382 non-null   object
#  3   Đơn vị          7382 non-null   int64
#  4   Tên đơn vị      7382 non-null   object
#  5   Tháng           7382 non-null   int64
#  6   Năm             7382 non-null   int64
#  7   Số lượng        7382 non-null   int64
#  8   Giá             7382 non-null   float64
#  9   Chiết khấu (%)  7382 non-null   int64
#  10  Tổng            7381 non-null   float64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 692.1+ KB

# %%
# Thêm 1 dòng mới vào đầu bảng
data.loc[-1] = ['Hà Nội', 3001, 'Cốm làng Vòng', 5, 'KG', 10, 2022, 20, 50.000, 30, np.NaN]
data
# Out:
#                Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
#  0     National Average     52            Rice - Retail       5         KG
#  1     National Average     52            Rice - Retail       5         KG
#  2     National Average     52            Rice - Retail       5         KG
#  3     National Average     52            Rice - Retail       5         KG
#  4     National Average     52            Rice - Retail       5         KG
# ...                 ...    ...                      ...     ...        ...
#  7377             Izmir    502  Cocoa (powder) - Retail       5         KG
#  7378             Izmir    502  Cocoa (powder) - Retail       5         KG
#  7379             Izmir    502  Cocoa (powder) - Retail       5         KG
#  7380             Izmir    502  Cocoa (powder) - Retail       5         KG
# -1               Hà Nội   3001            Cốm làng Vòng       5         KG
#
#        Tháng   Năm  Số lượng      Giá  Chiết khấu (%)      Tổng
#  0         5  2013        50   4.4920              20   179.680
#  1         6  2013        50   4.5786              20   183.144
#  2        11  2013        50   4.7865              20   191.460
#  3        12  2013        50   5.1337              20   205.348
#  4         1  2014        50   5.5099              20   220.396
# ...      ...   ...       ...      ...             ...       ...
#  7377      9  2019        50  49.1176              20  1964.704
#  7378     10  2019        50  50.8347              20  2033.388
#  7379     11  2019        50  51.7985              20  2071.940
#  7380     12  2019        50  51.6071              20  2064.284
# -1        10  2022        20  50.0000              30       NaN
#
# [7382 rows x 11 columns]

# %%
# Update index của bảng
data.index = data.index + 1
# Sắp xếp lại bảng
data = data.sort_index()
display(data)
# data.info()
# Out:
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0               Hà Nội   3001            Cốm làng Vòng       5         KG
# 1     National Average     52            Rice - Retail       5         KG
# 2     National Average     52            Rice - Retail       5         KG
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7377             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7378             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7379             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7381             Izmir    502  Cocoa (powder) - Retail       5         KG
#
#       Tháng   Năm  Số lượng      Giá  Chiết khấu (%)      Tổng
# 0        10  2022        20  50.0000              30       NaN
# 1         5  2013        50   4.4920              20   179.680
# 2         6  2013        50   4.5786              20   183.144
# 3        11  2013        50   4.7865              20   191.460
# 4        12  2013        50   5.1337              20   205.348
# ...     ...   ...       ...      ...             ...       ...
# 7377      8  2019        50  47.9040              20  1916.160
# 7378      9  2019        50  49.1176              20  1964.704
# 7379     10  2019        50  50.8347              20  2033.388
# 7380     11  2019        50  51.7985              20  2071.940
# 7381     12  2019        50  51.6071              20  2064.284
#
# [7382 rows x 11 columns]

# %%
Thêm 1 dòng mới vào sau dòng Hà Nội. Với các giá trị lần lượt là 
'Đà Nẵng',3002,'Mỳ Quảng',5,'Tô',10,2022,20, 100.000,10,np.NaN

# %%
data.index(0) = -1
data
# Out:
#   Input In [32]
#     data.index(0) = -1
#     ^
# SyntaxError: cannot assign to function call here. Maybe you meant '==' instead of '='?

# %%
data.loc[0.5] = ['Đà Nẵng', 3002, 'Mỳ quảng', 5, 'Tô', 10, 2022, 20, 100.000, 10, np.NaN]
data = data.sort_index()
data
# Out:
#                  Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# -0.5              Đà Nẵng   3002                 Mỳ quảng       5         Tô
#  0.0               Hà Nội   3001            Cốm làng Vòng       5         KG
#  0.5              Đà Nẵng   3002                 Mỳ quảng       5         Tô
#  1.0     National Average     52            Rice - Retail       5         KG
#  2.0     National Average     52            Rice - Retail       5         KG
# ...                   ...    ...                      ...     ...        ...
#  7378.0             Izmir    502  Cocoa (powder) - Retail       5         KG
#  7379.0             Izmir    502  Cocoa (powder) - Retail       5         KG
#  7380.0             Izmir    502  Cocoa (powder) - Retail       5         KG
#  7381.0             Izmir    502  Cocoa (powder) - Retail       5         KG
#  7382.0           Sài Gòn   3000                  Dưa hấu       5         KG
#
#          Tháng   Năm  Số lượng       Giá  Chiết khấu (%)      Tổng
# -0.5        10  2022        20  100.0000              10       NaN
#  0.0        10  2022        20   50.0000              30       NaN
#  0.5        10  2022        20  100.0000              10       NaN
#  1.0         5  2013        50    4.4920              20   179.680
#  2.0         6  2013        50    4.5786              20   183.144
# ...        ...   ...       ...       ...             ...       ...
#  7378.0      9  2019        50   49.1176              20  1964.704
#  7379.0     10  2019        50   50.8347              20  2033.388
#  7380.0     11  2019        50   51.7985              20  2071.940
#  7381.0     12  2019        50   51.6071              20  2064.284
#  7382.0     10  2022        50   50.0000              10       NaN
#
# [7385 rows x 11 columns]

# %%
data.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [39], in <cell line: 1>()
# ----> 1 data.del_index(-0.5)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:5907, in NDFrame.__getattr__(self, name)
#    5900 if (
#    5901     name not in self._internal_names_set
#    5902     and name not in self._metadata
#    5903     and name not in self._accessors
#    5904     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5905 ):
#    5906     return self[name]
# -> 5907 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'del_index'

# %% [markdown]
# # Xoá cột sử dụng del

# %% [markdown]
# ##

# %%
# Xoá cột sử dụng del
data2 = data
display(data2)
# Xoá cột 'Cột mới' (xoá ngay trên bảng gốc) -> Nguy hiểm, hạn chế dùng
del data2['Tổng']
print('Data2 sau khi xoá')
display(data2)
print('Data sau khi xoá')
display(data)
# Out:
#                  Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# -0.5              Đà Nẵng   3002                 Mỳ quảng       5         Tô
#  0.0               Hà Nội   3001            Cốm làng Vòng       5         KG
#  0.5              Đà Nẵng   3002                 Mỳ quảng       5         Tô
#  1.0     National Average     52            Rice - Retail       5         KG
#  2.0     National Average     52            Rice - Retail       5         KG
# ...                   ...    ...                      ...     ...        ...
#  7378.0             Izmir    502  Cocoa (powder) - Retail       5         KG
#  7379.0             Izmir    502  Cocoa (powder) - Retail       5         KG
#  7380.0             Izmir    502  Cocoa (powder) - Retail       5         KG
#  7381.0             Izmir    502  Cocoa (powder) - Retail       5         KG
#  7382.0           Sài Gòn   3000                  Dưa hấu       5         KG
#
#          Tháng   Năm  Số lượng       Giá  Chiết khấu (%)      Tổng
# -0.5        10  2022        20  100.0000              10       NaN
#  0.0        10  2022        20   50.0000              30       NaN
#  0.5        10  2022        20  100.0000              10       NaN
#  1.0         5  2013        50    4.4920              20   179.680
#  2.0         6  2013        50    4.5786              20   183.144
# ...        ...   ...       ...       ...             ...       ...
#  7378.0      9  2019        50   49.1176              20  1964.704
#  7379.0     10  2019        50   50.8347              20  2033.388
#  7380.0     11  2019        50   51.7985              20  2071.940
#  7381.0     12  2019        50   51.6071              20  2064.284
#  7382.0     10  2022        50   50.0000              10       NaN
#
# [7385 rows x 11 columns]
# Data2 sau khi xoá
#                  Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# -0.5              Đà Nẵng   3002                 Mỳ quảng       5         Tô
#  0.0               Hà Nội   3001            Cốm làng Vòng       5         KG
#  0.5              Đà Nẵng   3002                 Mỳ quảng       5         Tô
#  1.0     National Average     52            Rice - Retail       5         KG
#  2.0     National Average     52            Rice - Retail       5         KG
# ...                   ...    ...                      ...     ...        ...
#  7378.0             Izmir    502  Cocoa (powder) - Retail       5         KG
#  7379.0             Izmir    502  Cocoa (powder) - Retail       5         KG
#  7380.0             Izmir    502  Cocoa (powder) - Retail       5         KG
#  7381.0             Izmir    502  Cocoa (powder) - Retail       5         KG
#  7382.0           Sài Gòn   3000                  Dưa hấu       5         KG
#
#          Tháng   Năm  Số lượng       Giá  Chiết khấu (%)
# -0.5        10  2022        20  100.0000              10
#  0.0        10  2022        20   50.0000              30
#  0.5        10  2022        20  100.0000              10
#  1.0         5  2013        50    4.4920              20
#  2.0         6  2013        50    4.5786              20
# ...        ...   ...       ...       ...             ...
#  7378.0      9  2019        50   49.1176              20
#  7379.0     10  2019        50   50.8347              20
#  7380.0     11  2019        50   51.7985              20
#  7381.0     12  2019        50   51.6071              20
#  7382.0     10  2022        50   50.0000              10
#
# [7385 rows x 10 columns]
# Data sau khi xoá
#                  Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# -0.5              Đà Nẵng   3002                 Mỳ quảng       5         Tô
#  0.0               Hà Nội   3001            Cốm làng Vòng       5         KG
#  0.5              Đà Nẵng   3002                 Mỳ quảng       5         Tô
#  1.0     National Average     52            Rice - Retail       5         KG
#  2.0     National Average     52            Rice - Retail       5         KG
# ...                   ...    ...                      ...     ...        ...
#  7378.0             Izmir    502  Cocoa (powder) - Retail       5         KG
#  7379.0             Izmir    502  Cocoa (powder) - Retail       5         KG
#  7380.0             Izmir    502  Cocoa (powder) - Retail       5         KG
#  7381.0             Izmir    502  Cocoa (powder) - Retail       5         KG
#  7382.0           Sài Gòn   3000                  Dưa hấu       5         KG
#
#          Tháng   Năm  Số lượng       Giá  Chiết khấu (%)
# -0.5        10  2022        20  100.0000              10
#  0.0        10  2022        20   50.0000              30
#  0.5        10  2022        20  100.0000              10
#  1.0         5  2013        50    4.4920              20
#  2.0         6  2013        50    4.5786              20
# ...        ...   ...       ...       ...             ...
#  7378.0      9  2019        50   49.1176              20
#  7379.0     10  2019        50   50.8347              20
#  7380.0     11  2019        50   51.7985              20
#  7381.0     12  2019        50   51.6071              20
#  7382.0     10  2022        50   50.0000              10
#
# [7385 rows x 10 columns]

# %%
# Xoá cột sử dụng pop()
data3 = data
print('Data3 sau khi tạo')
display(data3)
# Xoá cột
# Out:
# Data3 sau khi tạo
#                  Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# -0.5              Đà Nẵng   3002                 Mỳ quảng       5         Tô
#  0.0               Hà Nội   3001            Cốm làng Vòng       5         KG
#  0.5              Đà Nẵng   3002                 Mỳ quảng       5         Tô
#  1.0     National Average     52            Rice - Retail       5         KG
#  2.0     National Average     52            Rice - Retail       5         KG
# ...                   ...    ...                      ...     ...        ...
#  7378.0             Izmir    502  Cocoa (powder) - Retail       5         KG
#  7379.0             Izmir    502  Cocoa (powder) - Retail       5         KG
#  7380.0             Izmir    502  Cocoa (powder) - Retail       5         KG
#  7381.0             Izmir    502  Cocoa (powder) - Retail       5         KG
#  7382.0           Sài Gòn   3000                  Dưa hấu       5         KG
#
#          Tháng   Năm  Số lượng       Giá  Chiết khấu (%)
# -0.5        10  2022        20  100.0000              10
#  0.0        10  2022        20   50.0000              30
#  0.5        10  2022        20  100.0000              10
#  1.0         5  2013        50    4.4920              20
#  2.0         6  2013        50    4.5786              20
# ...        ...   ...       ...       ...             ...
#  7378.0      9  2019        50   49.1176              20
#  7379.0     10  2019        50   50.8347              20
#  7380.0     11  2019        50   51.7985              20
#  7381.0     12  2019        50   51.6071              20
#  7382.0     10  2022        50   50.0000              10
#
# [7385 rows x 10 columns]

# %%
print("data")
display(data)
print("data2")
display(data2)
print("data3")
display(data3)
print("data4")
display(data4)
print("data4")
display(data5)
# Out:
# data
#                  Place  ProductId              ProductName  UmId UmName  \
# 0     National Average         52            Rice - Retail     5     KG
# 1     National Average         52            Rice - Retail     5     KG
# 2     National Average         52            Rice - Retail     5     KG
# 3     National Average         52            Rice - Retail     5     KG
# 4     National Average         52            Rice - Retail     5     KG
# ...                ...        ...                      ...   ...    ...
# 7376             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7377             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7378             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7379             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7380             Izmir        502  Cocoa (powder) - Retail     5     KG
#
#       Month  Year    Price
# 0         5  2013   4.4920
# 1         6  2013   4.5786
# 2        11  2013   4.7865
# 3        12  2013   5.1337
# 4         1  2014   5.5099
# ...     ...   ...      ...
# 7376      8  2019  47.9040
# 7377      9  2019  49.1176
# 7378     10  2019  50.8347
# 7379     11  2019  51.7985
# 7380     12  2019  51.6071
#
# [7381 rows x 8 columns]
# data2
#                  Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# -0.5              Đà Nẵng   3002                 Mỳ quảng       5         Tô
#  0.0               Hà Nội   3001            Cốm làng Vòng       5         KG
#  0.5              Đà Nẵng   3002                 Mỳ quảng       5         Tô
#  1.0     National Average     52            Rice - Retail       5         KG
#  2.0     National Average     52            Rice - Retail       5         KG
# ...                   ...    ...                      ...     ...        ...
#  7378.0             Izmir    502  Cocoa (powder) - Retail       5         KG
#  7379.0             Izmir    502  Cocoa (powder) - Retail       5         KG
#  7380.0             Izmir    502  Cocoa (powder) - Retail       5         KG
#  7381.0             Izmir    502  Cocoa (powder) - Retail       5         KG
#  7382.0           Sài Gòn   3000                  Dưa hấu       5         KG
#
#          Tháng   Năm  Số lượng       Giá  Chiết khấu (%)
# -0.5        10  2022        20  100.0000              10
#  0.0        10  2022        20   50.0000              30
#  0.5        10  2022        20  100.0000              10
#  1.0         5  2013        50    4.4920              20
#  2.0         6  2013        50    4.5786              20
# ...        ...   ...       ...       ...             ...
#  7378.0      9  2019        50   49.1176              20
#  7379.0     10  2019        50   50.8347              20
#  7380.0     11  2019        50   51.7985              20
#  7381.0     12  2019        50   51.6071              20
#  7382.0     10  2022        50   50.0000              10
#
# [7385 rows x 10 columns]
# data3
#                  Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# -0.5              Đà Nẵng   3002                 Mỳ quảng       5         Tô
#  0.0               Hà Nội   3001            Cốm làng Vòng       5         KG
#  0.5              Đà Nẵng   3002                 Mỳ quảng       5         Tô
#  1.0     National Average     52            Rice - Retail       5         KG
#  2.0     National Average     52            Rice - Retail       5         KG
# ...                   ...    ...                      ...     ...        ...
#  7378.0             Izmir    502  Cocoa (powder) - Retail       5         KG
#  7379.0             Izmir    502  Cocoa (powder) - Retail       5         KG
#  7380.0             Izmir    502  Cocoa (powder) - Retail       5         KG
#  7381.0             Izmir    502  Cocoa (powder) - Retail       5         KG
#  7382.0           Sài Gòn   3000                  Dưa hấu       5         KG
#
#          Tháng   Năm  Số lượng       Giá  Chiết khấu (%)
# -0.5        10  2022        20  100.0000              10
#  0.0        10  2022        20   50.0000              30
#  0.5        10  2022        20  100.0000              10
#  1.0         5  2013        50    4.4920              20
#  2.0         6  2013        50    4.5786              20
# ...        ...   ...       ...       ...             ...
#  7378.0      9  2019        50   49.1176              20
#  7379.0     10  2019        50   50.8347              20
#  7380.0     11  2019        50   51.7985              20
#  7381.0     12  2019        50   51.6071              20
#  7382.0     10  2022        50   50.0000              10
#
# [7385 rows x 10 columns]
# data4
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [50], in <cell line: 8>()
#       6 display(data3)
#       7 print("data4")
# ----> 8 display(data4)
#       9 print("data4")
#      10 display(data5)
#
# NameError: name 'data4' is not defined

# %%
data7 = data.drop(0, axis = 0)
display(data7)
data7.info()
# Out:
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 1     National Average     52            Rice - Retail       5         KG
# 2     National Average     52            Rice - Retail       5         KG
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# 5     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7377             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7378             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7379             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7381             Izmir    502  Cocoa (powder) - Retail       5         KG
#
#       Tháng   Năm  Số lượng      Giá  Chiết khấu (%)      Tổng
# 1         5  2013        50   4.4920              20   179.680
# 2         6  2013        50   4.5786              20   183.144
# 3        11  2013        50   4.7865              20   191.460
# 4        12  2013        50   5.1337              20   205.348
# 5         1  2014        50   5.5099              20   220.396
# ...     ...   ...       ...      ...             ...       ...
# 7377      8  2019        50  47.9040              20  1916.160
# 7378      9  2019        50  49.1176              20  1964.704
# 7379     10  2019        50  50.8347              20  2033.388
# 7380     11  2019        50  51.7985              20  2071.940
# 7381     12  2019        50  51.6071              20  2064.284
#
# [7381 rows x 11 columns]
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7381 entries, 1 to 7381
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Địa điểm        7381 non-null   object
#  1   Mã SP           7381 non-null   int64
#  2   Tên SP          7381 non-null   object
#  3   Đơn vị          7381 non-null   int64
#  4   Tên đơn vị      7381 non-null   object
#  5   Tháng           7381 non-null   int64
#  6   Năm             7381 non-null   int64
#  7   Số lượng        7381 non-null   int64
#  8   Giá             7381 non-null   float64
#  9   Chiết khấu (%)  7381 non-null   int64
#  10  Tổng            7381 non-null   float64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 692.0+ KB
