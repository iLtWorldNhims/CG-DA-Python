# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import ipywidgets as widgets
from ipywidgets import interact
import sqlalchemy as sql

# %%
host = 'mysql.anbelly.com'
user = 'hocvien'
password = '12345678'
database = 'casestudy'

# %%
engine = sql.create_engine(
    sql.engine.url.URL.create(
        drivername = "mysql",
        username = user,
        password = password,
        host = host,
        port = 3306,
        database = database,
    ),
    echo_pool=True,
)
print("Connecting with engine " + str(engine))

connection = engine.connect()

print('Connected')
# Out:
# Connecting with engine Engine(mysql://hocvien:***@mysql.anbelly.com:3306/casestudy)
# Connected

# %%
pd.read_sql_query("SHOW DATABASES", connection)
# Out:
#              Database
# 0            DA2209R1
# 1           casestudy
# 2  information_schema
# 3               mysql
# 4  performance_schema
# 5                 sys

# %%
pd.read_sql_query("SHOW TABLES", connection)
# Out:
#   Tables_in_casestudy
# 0           Catalogue
# 1            Category
# 2        Manufacturer
# 3               Sales

# %%
pd.read_sql_query("SELECT * FROM Sales", connection)
# Out:
#     Manufacturer       Model  Jan  Feb   Mar   Apr   May   Jun   Jul   Aug  \
# 0          Acura         MDX   93  389   782   611   550   501     0     0
# 1           Audi          Q7  210  210   236   303   292   303     0     0
# 2           Audi          Q8  130  130   146   211   203   211     0     0
# 3            BMW          X5  323  323   364   518   498   518     0     0
# 4            BMW          X6   72   72    81   113   108   113     0     0
# ..           ...         ...  ...  ...   ...   ...   ...   ...   ...   ...
# 231       Subaru     Outback  499  621   948  1065  1079   981  1074   845
# 232       Toyota     4Runner  605  393   784   762   854   681   824   903
# 233       Toyota  Highlander  729  792  1184  1095  1185  1423  1347  1336
# 234   Volkswagen          At  530  521   822   925   881   725   761   769
# 235   Volkswagen       Touar    7    2     5     2     1     3     2     0
#
#       Sep   Oct   Nov   Dec  Sumofsales  Year
# ...

# %%
pd.read_sql_query("SELECT * FROM Manufacturer", connection)
# Out:
#     index           name
# 0       0        Lincoln
# 1       1       Cadillac
# 2       2       Infiniti
# 3       3         Jaguar
# 4       4          Volvo
# 5       5  Mercedes0Benz
# 6       6         Nissan
# 7       7      Chevrolet
# 8       8     Volkswagen
# 9       9           Ford
# 10     10     Alfa Romeo
# 11     11            BMW
# 12     12     Land Rover
# 13     13           Audi
# 14     14          Tesla
# 15     15            Kia
# 16     16          Lexus
# 17     17          Mazda
# 18     18         Subaru
# 19     19            GMC
# 20     20          Dodge
# 21     21          Buick
# 22     22         Toyota
# 23     23          Honda
# 24     24           Jeep
# 25     25        Hyundai
# 26     26          Acura
# 27     27        Porsche
# 28     28       Maserati
# 29     29        Genesis

# %%
pd.read_sql_query("SELECT * FROM Category", connection)
# Out:
#   Category         Description
# 0      LLS   Large Luxury Size
# 1       LS          Large Size
# 2      MLS  Medium Luxury Size
# 3       MS         Medium Size
# 4      SLS   Small Luxury Size
# 5       SS          Small Size

# %%
pd.read_sql_query("SELECT * FROM Catalogue", connection)
# Out:
#    Manufacturer         Model  Price_in_thousands  Engine_size  Horsepower  \
# 0       Lincoln  MKX/Nautilus              28.400          3.2       225.0
# 1      Cadillac           XT4              21.975          3.1       175.0
# 2      Infiniti          QX60              25.300          3.8       240.0
# 3        Jaguar        E0Pace              31.965          3.8       205.0
# 4         Volvo          XC60              27.885          3.8       205.0
# ..          ...           ...                 ...          ...         ...
# 84     Infiniti          QX30              16.888          2.0       127.0
# 85          BMW            X5              22.288          2.7       150.0
# 86       Nissan    Pathfinder              16.700          2.0       115.0
# 87         Audi            Q7              21.200          1.8       150.0
# 88   Land Rover             g              15.900          2.0       115.0
#
# ...

# %%
pd.read_sql_query("SELECT * FROM schedulesDF", connection)
# Out:
#                  start                 end
# 0  2022-09-30 19:30:00 2022-09-30 21:30:00
# 1  2022-10-03 19:30:00 2022-10-03 21:30:00
# 2  2022-10-05 19:30:00 2022-10-05 21:30:00
# 3  2022-10-07 19:30:00 2022-10-07 21:30:00
# 4  2022-10-10 19:30:00 2022-10-10 21:30:00
# 5  2022-10-12 19:30:00 2022-10-12 21:30:00
# 6  2022-10-14 19:30:00 2022-10-14 21:30:00
# 7  2022-10-17 19:30:00 2022-10-17 21:30:00
# 8  2022-10-19 19:30:00 2022-10-19 21:30:00
# 9  2022-10-21 19:30:00 2022-10-21 21:30:00
# 10 2022-10-24 19:30:00 2022-10-24 21:30:00
# 11 2022-10-26 19:30:00 2022-10-26 21:30:00
# 12 2022-10-28 19:30:00 2022-10-28 21:30:00
# 13 2022-10-31 19:30:00 2022-10-31 21:30:00
# 14 2022-11-02 19:30:00 2022-11-02 21:30:00
# 15 2022-11-04 19:30:00 2022-11-04 21:30:00
# 16 2022-11-07 19:30:00 2022-11-07 21:30:00
# 17 2022-11-09 19:30:00 2022-11-09 21:30:00
# 18 2022-11-11 19:30:00 2022-11-11 21:30:00
# 19 2022-11-14 19:30:00 2022-11-14 21:30:00
# 20 2022-11-16 19:30:00 2022-11-16 21:30:00
# ...

# %%
pd.read_sql_query("SELECT * FROM Checka", connection)
# Out:
#                      name                              email 2022-09-30  \
# 0      Nguyễn Thị Ngọc Hà        ha.nguyen.hvnh.vn@gmail.com      FALSE
# 1      Lê Thị Tuyết Nhung  nhungle.31201024509@st.ueh.edu.vn      FALSE
# 2            Lê Mạnh Hùng                 hungubbc@gmail.com      FALSE
# 3           Phan Tiến Đạt          tiendatphan1194@gmail.com      FALSE
# 4          Huỳnh Tấn Hùng            hunght.fin.92@gmail.com      FALSE
# 5           Phạm Thị Hằng           hptphamthihang@gmail.com      FALSE
# 6        Phan Thị Minh Tú          phanthiminhtu31@gmail.com      FALSE
# 7         Nguyễn Thế Vinh                nt.vinh92@gmail.com      FALSE
# 8           Ngô Quang Đức                 ducnq.vt@gmail.com      FALSE
# 9    Nguyễn Thành Trinh       thanhtrinh08011997@gmail.com      FALSE
# 10        Nguyễn Mạnh Huy                 mahh.huy@gmail.com      FALSE
# 11              Tạ Văn Vỹ            tavanvy210299@gmail.com      FALSE
# ...

# %%
cat = pd.read_sql_query("SELECT * FROM Catalogue", connection)
cat
# Out:
#    Manufacturer         Model  Price_in_thousands  Engine_size  Horsepower  \
# 0       Lincoln  MKX/Nautilus              28.400          3.2       225.0
# 1      Cadillac           XT4              21.975          3.1       175.0
# 2      Infiniti          QX60              25.300          3.8       240.0
# 3        Jaguar        E0Pace              31.965          3.8       205.0
# 4         Volvo          XC60              27.885          3.8       205.0
# ..          ...           ...                 ...          ...         ...
# 84     Infiniti          QX30              16.888          2.0       127.0
# 85          BMW            X5              22.288          2.7       150.0
# 86       Nissan    Pathfinder              16.700          2.0       115.0
# 87         Audi            Q7              21.200          1.8       150.0
# 88   Land Rover             g              15.900          2.0       115.0
#
# ...

# %%
cat.dtypes
# Out:
# Manufacturer                  object
# Model                         object
# Price_in_thousands           float64
# Engine_size                  float64
# Horsepower                   float64
# Wheelbase                    float64
# Width                        float64
# Length                       float64
# Curb_weight                  float64
# Fuel_capacity                float64
# Fuel_efficiency              float64
# Latest_Launch         datetime64[ns]
# Power_perf_factor            float64
# dtype: object

# %%
cat.describe()
# Out:
#        Price_in_thousands  Engine_size  Horsepower   Wheelbase      Width  \
# count           89.000000    89.000000   89.000000   89.000000  89.000000
# mean            21.144191     2.928090  168.258427  108.303371  71.115730
# std              7.333770     0.889329   40.722042    8.205603   3.533505
# min              9.699000     1.500000   92.000000   93.400000  65.700000
# 25%             16.535000     2.200000  135.000000  103.200000  68.300000
# 50%             20.230000     3.000000  170.000000  107.000000  70.400000
# 75%             24.495000     3.500000  200.000000  112.200000  73.100000
# max             49.900000     5.200000  275.000000  138.700000  79.300000
#
#            Length  Curb_weight  Fuel_capacity  Fuel_efficiency  \
# count   89.000000    89.000000      89.000000        87.000000
# mean   188.726966     3.294584      17.494382        24.413793
# std     13.800204     0.582291       3.656046         4.152757
# ...

# %%
cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Manufacturer        89 non-null     object
#  1   Model               89 non-null     object
#  2   Price_in_thousands  89 non-null     float64
#  3   Engine_size         89 non-null     float64
#  4   Horsepower          89 non-null     float64
#  5   Wheelbase           89 non-null     float64
#  6   Width               89 non-null     float64
#  7   Length              89 non-null     float64
#  8   Curb_weight         89 non-null     float64
#  9   Fuel_capacity       89 non-null     float64
#  10  Fuel_efficiency     87 non-null     float64
#  11  Latest_Launch       89 non-null     datetime64[ns]
#  12  Power_perf_factor   89 non-null     float64
# dtypes: datetime64[ns](1), float64(10), object(2)
# memory usage: 9.2+ KB
