# %% [markdown]
# # 1. Đọc bộ dữ liệu, cho biết số dòng, số cột và kiểu dữ liệu của các thuộc tính.

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\MY PC\Documents\GitHub\CG-DA-Python\Datasets\GDPList.csv", encoding = "ISO-8859-1")
df
# Out:
#           Country      Continent  GDP (millions of US$)
# 0     Afghanistan           Asia                  18181
# 1         Albania         Europe                  12847
# 2         Algeria         Africa                 190709
# 3          Angola         Africa                 100948
# 4       Argentina  South America                 447644
# ..            ...            ...                    ...
# 120    Uzbekistan           Asia                  45353
# 121     Venezuela  South America                 315841
# 122       Vietnam           Asia                 122722
# 123         Yemen         Africa                  33675
# 124        Zambia         Africa                  19206
#
# [125 rows x 3 columns]

# %%
print("Số dòng dữ liệu:", df.shape[0])
print("Số cột dữ liệu:", df.shape[1])
# Out:
# Số dòng dữ liệu: 125
# Số cột dữ liệu: 3

# %%
df.dtypes
# Out:
# Country                  object
# Continent                object
# GDP (millions of US$)     int64
# dtype: object

# %% [markdown]
# # 2. Việt hóa tên các cột trong bảng dữ liệu: Country 🡪 Nuoc; Continent 🡪 Chauluc; GDP (millions of US$\$) 🡪 GDP (trieu $ \$)

# %%
df.rename(columns = {'Country': 'Nước', 'Continent': 'Châu lục', 'GDP (millions of US$)': 'GDP (triệu $)'}, inplace = True)
df
# Out:
#              Nước       Châu lục  GDP (triệu $)
# 0     Afghanistan           Asia          18181
# 1         Albania         Europe          12847
# 2         Algeria         Africa         190709
# 3          Angola         Africa         100948
# 4       Argentina  South America         447644
# ..            ...            ...            ...
# 120    Uzbekistan           Asia          45353
# 121     Venezuela  South America         315841
# 122       Vietnam           Asia         122722
# 123         Yemen         Africa          33675
# 124        Zambia         Africa          19206
#
# [125 rows x 3 columns]

# %% [markdown]
# # 3. Chèn thêm một cột “Thanhpho” vào sau cột “Nuoc”, giá trị ban đầu là giá trị của cột “Nuoc”

# %%
df.insert(1, 'Thành phố', pd.Series(df.loc[:, 'Nước'], index = df.index))

# %%
df
# Out:
#              Nước     Thành phố       Châu lục  GDP (triệu $)
# 0     Afghanistan   Afghanistan           Asia          18181
# 1         Albania       Albania         Europe          12847
# 2         Algeria       Algeria         Africa         190709
# 3          Angola        Angola         Africa         100948
# 4       Argentina     Argentina  South America         447644
# ..            ...           ...            ...            ...
# 120    Uzbekistan    Uzbekistan           Asia          45353
# 121     Venezuela     Venezuela  South America         315841
# 122       Vietnam       Vietnam           Asia         122722
# 123         Yemen         Yemen         Africa          33675
# 124        Zambia        Zambia         Africa          19206
#
# [125 rows x 4 columns]

# %% [markdown]
# # 4. Trong cột Thanhpho, thay giá trị Vietnam thành Hanoi; Làm tương tự với các nước còn lại.

# %%
df['Thành phố'].unique()
# Out:
# array(['\xa0Afghanistan', '\xa0Albania', '\xa0Algeria', '\xa0Angola',
#        '\xa0Argentina', '\xa0Australia', '\xa0Austria', '\xa0Azerbaijan',
#        '\xa0Bahrain', '\xa0Bangladesh', '\xa0Belarus', '\xa0Belgium',
#        '\xa0Bolivia', '\xa0Bosnia and Herzegovina', '\xa0Botswana',
#        '\xa0Brazil', '\xa0Brunei', '\xa0Bulgaria', '\xa0Burma',
#        '\xa0Cambodia', '\xa0Cameroon', '\xa0Canada', '\xa0Chile',
#        '\xa0China', '\xa0Colombia',
#        '\xa0Congo, Democratic Republic of the',
#        '\xa0Congo, Republic of the', '\xa0Costa Rica',
#        "\xa0Côte d'Ivoire", '\xa0Croatia', '\xa0Cyprus',
#        '\xa0Czech Republic', '\xa0Denmark', '\xa0Dominican Republic',
#        '\xa0Ecuador', '\xa0Egypt', '\xa0El Salvador',
#        '\xa0Equatorial Guinea', '\xa0Estonia', '\xa0Ethiopia',
#        '\xa0Finland', '\xa0France', '\xa0Gabon', '\xa0Georgia',
#        '\xa0Germany', '\xa0Ghana', '\xa0Greece', '\xa0Guatemala',
# ...

# %%
df['Thành phố'] = df['Thành phố'].replace('\xa0Vietnam', 'Hanoi')

# %%
df['Thành phố'] = df['Thành phố'].replace(['\xa0Afghanistan', '\xa0Albania', '\xa0Algeria', '\xa0Angola', '\xa0Argentina'], ['Kabul', 'Tirana', 'Algiers', 'Luanda', 'Buenos Aires'])

# %%
df['Thành phố'] = df['Thành phố'].replace(['\xa0Uzbekistan', '\xa0Venezuela', '\xa0Yemen', '\xa0Zambia'], ['Tashkent', 'Caracas', 'Sanaa', 'Lusaka'])

# %%
df
# Out:
#              Nước     Thành phố       Châu lục  GDP (triệu $)
# 0     Afghanistan         Kabul           Asia          18181
# 1         Albania        Tirana         Europe          12847
# 2         Algeria       Algiers         Africa         190709
# 3          Angola        Luanda         Africa         100948
# 4       Argentina  Buenos Aires  South America         447644
# ..            ...           ...            ...            ...
# 120    Uzbekistan      Tashkent           Asia          45353
# 121     Venezuela       Caracas  South America         315841
# 122       Vietnam         Hanoi           Asia         122722
# 123         Yemen         Sanaa         Africa          33675
# 124        Zambia        Lusaka         Africa          19206
#
# [125 rows x 4 columns]

# %% [markdown]
# # 5. Xóa các bản ghi có Chauluc là ‘Asia’

# %%
df.drop(df.loc[df['Châu lục'] == 'Asia'].index, inplace = True)
df
# Out:
#                Nước       Thành phố       Châu lục  GDP (triệu $)
# 1           Albania          Tirana         Europe          12847
# 2           Algeria         Algiers         Africa         190709
# 3            Angola          Luanda         Africa         100948
# 4         Argentina    Buenos Aires  South America         447644
# 5         Australia       Australia        Oceania        1488221
# ..              ...             ...            ...            ...
# 118   United States   United States  North America       15094025
# 119         Uruguay         Uruguay  South America          46872
# 121       Venezuela         Caracas  South America         315841
# 123           Yemen           Sanaa         Africa          33675
# 124          Zambia          Lusaka         Africa          19206
#
# [89 rows x 4 columns]

# %%
df['Châu lục'].unique()
# Out:
# array(['Europe', 'Africa', 'South America', 'Oceania', 'North America'],
#       dtype=object)

# %% [markdown]
# # 6. Xóa các bản ghi có GDP < 300000

# %%
df.drop(df.loc[df['GDP (triệu $)'] < 300000].index, inplace = True)
df
# Out:
#                 Nước        Thành phố       Châu lục  GDP (triệu $)
# 4          Argentina     Buenos Aires  South America         447644
# 5          Australia        Australia        Oceania        1488221
# 6            Austria          Austria         Europe         419243
# 11           Belgium          Belgium         Europe         513396
# 15            Brazil           Brazil  South America        2492908
# 21            Canada           Canada  North America        1736869
# 24          Colombia         Colombia  South America         328422
# 32           Denmark          Denmark         Europe         333238
# 41            France           France         Europe        2776324
# 44           Germany          Germany         Europe        3577031
# 46            Greece           Greece         Europe         303065
# 58             Italy            Italy         Europe        2198730
# 73            Mexico           Mexico  North America        1154784
# ...

# %%
df['GDP (triệu $)'] >= 300000
# Out:
# 4      True
# 5      True
# 6      True
# 11     True
# 15     True
# 21     True
# 24     True
# 32     True
# 41     True
# 44     True
# 46     True
# 58     True
# 73     True
# 78     True
# 81     True
# 89     True
# 100    True
# 102    True
# 105    True
# 106    True
# 117    True
# 118    True
# 121    True
# Name: GDP (triệu $), dtype: bool
