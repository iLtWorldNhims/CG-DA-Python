# %%
# Đọc dữ liệu vào DataFrame
import pandas as pd
df=pd.read_csv(filepath_or_buffer = r'C:\Users\MY PC\Documents\GitHub\CG-DA-Python\Datasets\FoodPrice_in_Turkey.csv', sep = ',')
df.head()
# Out:
#               Place  ProductId    ProductName  UmId UmName  Month  Year  \
# 0  National Average         52  Rice - Retail     5     KG      5  2013
# 1  National Average         52  Rice - Retail     5     KG      6  2013
# 2  National Average         52  Rice - Retail     5     KG     11  2013
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 4  National Average         52  Rice - Retail     5     KG      1  2014
#
#     Price
# 0  4.4920
# 1  4.5786
# 2  4.7865
# 3  5.1337
# 4  5.5099

# %%
df.to_csv('demo_FoodPrice.csv')

# %%
pd.read_csv('demo_FoodPrice.csv')
# Out:
#       Unnamed: 0             Place  ProductId              ProductName  UmId  \
# 0              0  National Average         52            Rice - Retail     5
# 1              1  National Average         52            Rice - Retail     5
# 2              2  National Average         52            Rice - Retail     5
# 3              3  National Average         52            Rice - Retail     5
# 4              4  National Average         52            Rice - Retail     5
# ...          ...               ...        ...                      ...   ...
# 7376        7376             Izmir        502  Cocoa (powder) - Retail     5
# 7377        7377             Izmir        502  Cocoa (powder) - Retail     5
# 7378        7378             Izmir        502  Cocoa (powder) - Retail     5
# 7379        7379             Izmir        502  Cocoa (powder) - Retail     5
# 7380        7380             Izmir        502  Cocoa (powder) - Retail     5
#
#      UmName  Month  Year    Price
# ...

# %%
df.to_excel('demo_FoodPrice.xlsx')

# %%
pd.read_excel('demo_FoodPrice.xlsx')
# Out:
#       Unnamed: 0             Place  ProductId              ProductName  UmId  \
# 0              0  National Average         52            Rice - Retail     5
# 1              1  National Average         52            Rice - Retail     5
# 2              2  National Average         52            Rice - Retail     5
# 3              3  National Average         52            Rice - Retail     5
# 4              4  National Average         52            Rice - Retail     5
# ...          ...               ...        ...                      ...   ...
# 7376        7376             Izmir        502  Cocoa (powder) - Retail     5
# 7377        7377             Izmir        502  Cocoa (powder) - Retail     5
# 7378        7378             Izmir        502  Cocoa (powder) - Retail     5
# 7379        7379             Izmir        502  Cocoa (powder) - Retail     5
# 7380        7380             Izmir        502  Cocoa (powder) - Retail     5
#
#      UmName  Month  Year    Price
# ...

# %%
df.to_json('demo_FoodPrice.json', orient='columns')

# %%
pd.read_json('demo_FoodPrice.json')
# Out:
#                  Place  ProductId              ProductName  UmId UmName  \
# 0     National Average         52            Rice - Retail     5     KG
# 1     National Average         52            Rice - Retail     5     KG
# 2     National Average         52            Rice - Retail     5     KG
# 3     National Average         52            Rice - Retail     5     KG
# 4     National Average         52            Rice - Retail     5     KG
# ...                ...        ...                      ...   ...    ...
# 7376             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7377             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7378             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7379             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7380             Izmir        502  Cocoa (powder) - Retail     5     KG
#
#       Month  Year    Price
# 0         5  2013   4.4920
# 1         6  2013   4.5786
# ...

# %%
df.to_hdf('demo_FoodPrice.h5', 'table')

# %%
pd.read_hdf('demo_FoodPrice.h5', 'table')
# Out:
#                  Place  ProductId              ProductName  UmId UmName  \
# 0     National Average         52            Rice - Retail     5     KG
# 1     National Average         52            Rice - Retail     5     KG
# 2     National Average         52            Rice - Retail     5     KG
# 3     National Average         52            Rice - Retail     5     KG
# 4     National Average         52            Rice - Retail     5     KG
# ...                ...        ...                      ...   ...    ...
# 7376             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7377             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7378             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7379             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7380             Izmir        502  Cocoa (powder) - Retail     5     KG
#
#       Month  Year    Price
# 0         5  2013   4.4920
# 1         6  2013   4.5786
# ...

# %%
df.to_html('demo_FoodPrice.html')

# %%
pd.read_html('demo_FoodPrice.html')
# Out:
# [      Unnamed: 0             Place  ProductId              ProductName  UmId  \
#  0              0  National Average         52            Rice - Retail     5
#  1              1  National Average         52            Rice - Retail     5
#  2              2  National Average         52            Rice - Retail     5
#  3              3  National Average         52            Rice - Retail     5
#  4              4  National Average         52            Rice - Retail     5
#  ...          ...               ...        ...                      ...   ...
#  7376        7376             Izmir        502  Cocoa (powder) - Retail     5
#  7377        7377             Izmir        502  Cocoa (powder) - Retail     5
#  7378        7378             Izmir        502  Cocoa (powder) - Retail     5
#  7379        7379             Izmir        502  Cocoa (powder) - Retail     5
#  7380        7380             Izmir        502  Cocoa (powder) - Retail     5
#
# ...
