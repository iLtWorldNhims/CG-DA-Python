# %%
import pandas as pd
data = pd.read_csv('C:\\Users\\ADMIN\\Documents\\CG-DA-Python\\DA - Datasets\\GDPlist.csv', encoding = 'ISO-8859-1')
data
# Out:
#           Country      Continent  GDP (millions of US$)
# 0     Afghanistan           Asia                  18181
# 1         Albania         Europe                  12847
# 2         Algeria         Africa                 190709
# 3          Angola         Africa                 100948
# 4       Argentina  South America                 447644
# ..            ...            ...                    ...
# 120    Uzbekistan           Asia                  45353
# 121     Venezuela  South America                 315841
# 122       Vietnam           Asia                 122722
# 123         Yemen         Africa                  33675
# 124        Zambia         Africa                  19206
#
# [125 rows x 3 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                125 non-null    object
#  1   Continent              125 non-null    object
#  2   GDP (millions of US$)  125 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 3.1+ KB

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(30, 30))
x = data['Country']
y = data['GDP (millions of US$)']
plt.bar(x,y)
plt.show()

# %%
data.groupby('Continent')['Country'].size()
# Out:
# Continent
# Africa           29
# Asia             36
# Europe           37
# North America    11
# Oceania           3
# South America     9
# Name: Country, dtype: int64

# %%
data.groupby('Continent')['GDP (millions of US$)'].sum()
# Out:
# Continent
# Africa            1820811
# Asia             24425891
# Europe           19139380
# North America    18238447
# Oceania           1662727
# South America     4141217
# Name: GDP (millions of US$), dtype: int64

# %%
data.loc['China']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [59], line 1
# ----> 1 data.loc['China']
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:1074, in _LocationIndexer.__getitem__(self, key)
#    1071 axis = self.axis or 0
#    1073 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1074 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:1313, in _LocIndexer._getitem_axis(self, key, axis)
#    1311 # fall thru to straight lookup
#    1312 self._validate_key(key, axis)
# -> 1313 return self._get_label(key, axis=axis)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:1261, in _LocIndexer._get_label(self, label, axis)
#    1259 def _get_label(self, label, axis: int):
# ...
