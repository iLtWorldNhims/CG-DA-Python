# %% [markdown]
# ### Import thư viện pandas và đọc dữ liệu từ file csv:

# %%
import pandas as pd
data = pd.read_csv(r'C:\Users\MY PC\Documents\GitHub\CG-DA-Python\DA - Datasets\GDPlist.csv', encoding = 'ISO-8859-1')
data
# Out:
#           Country      Continent  GDP (millions of US$)
# 0     Afghanistan           Asia                  18181
# 1         Albania         Europe                  12847
# 2         Algeria         Africa                 190709
# 3          Angola         Africa                 100948
# 4       Argentina  South America                 447644
# ..            ...            ...                    ...
# 120    Uzbekistan           Asia                  45353
# 121     Venezuela  South America                 315841
# 122       Vietnam           Asia                 122722
# 123         Yemen         Africa                  33675
# 124        Zambia         Africa                  19206
#
# [125 rows x 3 columns]

# %% [markdown]
# # Bộ dữ liệu chứa bao nhiêu dòng, bao nhiêu cột?
# # Thang đo tương ứng của các thuộc tính được lưu trữ?

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                125 non-null    object
#  1   Continent              125 non-null    object
#  2   GDP (millions of US$)  125 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 3.1+ KB

# %% [markdown]
# ## --> *Bộ dữ liệu chứa 125 dòng và 3 cột*

# %% [markdown]
# ## --> *Các thuộc tính:*
# ### - "Country" và "Continent" thuộc thang đo Nominal
# ### - "GDP" thuộc thang đo Ratio

# %% [markdown]
# # GDP của các quốc gia có đồng đều không?

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(30, 30))
x = data['Country']
y = data['GDP (millions of US$)']
plt.bar(x, y)
plt.show()

# %% [markdown]
# ## --> *GPD của các quốc gia không đồng đều*

# %% [markdown]
# # Mỗi châu lục có bao nhiêu quốc gia nằm trong bảng dữ liệu?

# %%
data.groupby('Continent')['Country'].size()
# Out:
# Continent
# Africa           29
# Asia             36
# Europe           37
# North America    11
# Oceania           3
# South America     9
# Name: Country, dtype: int64

# %% [markdown]
# ## --> *Các châu lục có số quốc gia nằm trong bảng dữ liệu là:*
# ### - Châu Phi có: 29 quốc gia
# ### - Châu Á có: 36 quốc gia
# ### - Châu Âu có: 37 quốc gia
# ### - Châu Bắc Mỹ có: 11 quốc gia
# ### - Châu Đại Dương có: 3 quốc gia
# ### - Châu Nam Mỹ có: 9 quốc gia

# %% [markdown]
# # Tổng GPD của các châu lục:

# %%
data.groupby('Continent')['GDP (millions of US$)'].sum()
# Out:
# Continent
# Africa            1820811
# Asia             24425891
# Europe           19139380
# North America    18238447
# Oceania           1662727
# South America     4141217
# Name: GDP (millions of US$), dtype: int64

# %% [markdown]
# ## --> *Tổng GDP của các châu lục là:*
# ### - Châu Phi: 1.820.811 triệu đô la Mỹ
# ### - Châu Á: 24.425.891 triệu đô la Mỹ
# ### - Châu Âu: 19.139.380 triệu đô la Mỹ
# ### - Châu Bắc Mỹ: 18.238.447 triệu đô la Mỹ
# ### - Châu Đại Dương: 1.662.727 triệu đô la Mỹ
# ### - Châu Nam Mỹ: 4.141.217 triệu đô la Mỹ

# %% [markdown]
# # Top 10 quốc gia có GDP cao nhất:

# %%
data_sorted = data.sort_values('GDP (millions of US$)', ascending = False)
data_sorted.head(10)['Country']
# Out:
# 118      United States
# 23               China
# 60               Japan
# 44             Germany
# 41              France
# 15              Brazil
# 117     United Kingdom
# 58               Italy
# 93              Russia
# 21              Canada
# Name: Country, dtype: object

# %% [markdown]
# ## --> Top 10 quốc gia có GDP cao nhất là:
# ### 1. Hoa Kỳ
# ### 2. Trung Quốc
# ### 3. Nhật Bản
# ### 4. Đức
# ### 5. Pháp
# ### 6. Bra-xin
# ### 7. Vương quốc Anh
# ### 8. Ý
# ### 9. Nga
# ### 10. Canada
