# %%
import pandas as pd

# %%
data = pd.read_csv(r'C:\Users\MY PC\Documents\GitHub\CG-DA-Python\Datasets\FoodPrice_in_Turkey.csv', encoding = 'ISO-8859-1')

# %%
data.head()
# Out:
#               Place  ProductId    ProductName  UmId UmName  Month  Year  \
# 0  National Average         52  Rice - Retail     5     KG      5  2013
# 1  National Average         52  Rice - Retail     5     KG      6  2013
# 2  National Average         52  Rice - Retail     5     KG     11  2013
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 4  National Average         52  Rice - Retail     5     KG      1  2014
#
#     Price
# 0  4.4920
# 1  4.5786
# 2  4.7865
# 3  5.1337
# 4  5.5099

# %%
data
# Out:
#                  Place  ProductId              ProductName  UmId UmName  \
# 0     National Average         52            Rice - Retail     5     KG
# 1     National Average         52            Rice - Retail     5     KG
# 2     National Average         52            Rice - Retail     5     KG
# 3     National Average         52            Rice - Retail     5     KG
# 4     National Average         52            Rice - Retail     5     KG
# ...                ...        ...                      ...   ...    ...
# 7376             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7377             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7378             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7379             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7380             Izmir        502  Cocoa (powder) - Retail     5     KG
#
#       Month  Year    Price
# 0         5  2013   4.4920
# 1         6  2013   4.5786
# ...

# %%
products_in_each_place = data.groupby('Place')['ProductName'].unique()

# %%
products_in_each_place
# Out:
# Place
# Ankara              [Rice - Retail, Wheat flour - Retail, Beans (w...
# Istanbul            [Rice - Retail, Wheat flour - Retail, Beans (w...
# Izmir               [Rice - Retail, Wheat flour - Retail, Beans (w...
# National Average    [Rice - Retail, Wheat flour - Retail, Beans (w...
# Name: ProductName, dtype: object

# %%
data['ProductName'].unique().sort()

# %%
products = data['ProductName'].unique()
products.sort()
products
# Out:
# array(['Apples (red) - Retail', 'Apples - Retail', 'Bananas - Retail',
#        'Beans (white) - Retail', 'Bread (common) - Retail',
#        'Bread (pita) - Retail', 'Bulgur - Retail', 'Cabbage - Retail',
#        'Cauliflower - Retail', 'Cheese - Retail', 'Chickpeas - Retail',
#        'Cocoa (powder) - Retail', 'Coffee (instant) - Retail',
#        'Coffee - Retail', 'Cucumbers (greenhouse) - Retail',
#        'Cucumbers - Retail', 'Eggplants - Retail', 'Eggs - Retail',
#        'Electricity - Retail', 'Fish (fresh) - Retail',
#        'Fuel (gas) - Retail', 'Fuel (petrol-gasoline) - Retail',
#        'Garlic - Retail', 'Groundnuts (shelled) - Retail',
#        'Lentils - Retail', 'Meat (chicken) - Retail',
#        'Meat (mutton) - Retail', 'Meat (veal) - Retail',
#        'Milk (pasteurized) - Retail',
#        'Milk (powder, infant formula) - Retail', 'Oil (olive) - Retail',
#        'Oil (sunflower) - Retail', 'Onions - Retail', 'Oranges - Retail',
# ...

# %%
type(products)
# Out:
# numpy.ndarray

# %%
places = data['Place'].unique()
places.sort()
print(places)
# Out:
# ['Ankara' 'Istanbul' 'Izmir' 'National Average']

# %%
places
# Out:
# array(['Ankara', 'Istanbul', 'Izmir', 'National Average'], dtype=object)

# %%
display(places)
# Out:
# array(['Ankara', 'Istanbul', 'Izmir', 'National Average'], dtype=object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7381 entries, 0 to 7380
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Place        7381 non-null   object
#  1   ProductId    7381 non-null   int64
#  2   ProductName  7381 non-null   object
#  3   UmId         7381 non-null   int64
#  4   UmName       7381 non-null   object
#  5   Month        7381 non-null   int64
#  6   Year         7381 non-null   int64
#  7   Price        7381 non-null   float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 461.4+ KB

# %% [markdown]
# # Bộ dữ liệu có 7381 dòng và 8 cột

# %% [markdown]
# # Place, ProductId, ProductName, UmId, UmName, Month và Year là những thuộc tính thuộc thang đo Nominal (Định danh)
# # Còn Price là thuộc tính thuộc thang đo Ratio (Tỉ lệ)

# %%
average_price = data.groupby(['ProductId', 'ProductName'])['Price'].mean()

# %%
type(average_price)
# Out:
# pandas.core.series.Series

# %%
average_price
# Out:
# ProductId  ProductName
# 52         Rice - Retail                                               7.950325
# 58         Wheat flour - Retail                                        3.253174
# 66         Beans (white) - Retail                                      9.572830
# 83         Potatoes - Retail                                           2.297231
# 92         Eggs - Retail                                               0.505925
# 94         Meat (chicken) - Retail                                     9.683471
# 97         Sugar - Retail                                              4.482942
# 105        Garlic - Retail                                            16.610370
# 108        Lentils - Retail                                            6.651817
# 112        Pasta - Retail                                              3.496637
# 114        Tomatoes - Retail                                           3.393658
# ...

# %%
average_price.sort_values()
# Out:
# ProductId  ProductName
# 92         Eggs - Retail                                               0.505925
# 491        Electricity - Retail                                        0.513580
# 181        Cabbage - Retail                                            1.723395
# 185        Salt - Retail                                               2.048213
# 173        Onions - Retail                                             2.141539
# 233        Cucumbers (greenhouse) - Retail                             2.206807
# 83         Potatoes - Retail                                           2.297231
# 229        Apples (red) - Retail                                       2.392193
# 384        Bread (pita) - Retail                                       2.404545
# 304        Transport (public) - Retail                                 2.468031
# 212        Peas (green, dry) - Retail                                  2.900029
# ...

# %%
average_price_df = pd.DataFrame(data.groupby(['ProductId', 'ProductName'])['Price'].mean())

# %%
type(average_price_df)
# Out:
# pandas.core.frame.DataFrame

# %%
average_price
# Out:
#                                                                    Price
# ProductId ProductName
# 52        Rice - Retail                                         7.950325
# 58        Wheat flour - Retail                                  3.253174
# 66        Beans (white) - Retail                                9.572830
# 83        Potatoes - Retail                                     2.297231
# 92        Eggs - Retail                                         0.505925
# 94        Meat (chicken) - Retail                               9.683471
# 97        Sugar - Retail                                        4.482942
# 105       Garlic - Retail                                      16.610370
# 108       Lentils - Retail                                      6.651817
# 112       Pasta - Retail                                        3.496637
# 114       Tomatoes - Retail                                     3.393658
# 119       Groundnuts (shelled) - Retail                        21.832122
# ...

# %%
type(average_price)
# Out:
# pandas.core.frame.DataFrame

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
average_price.sort_values()
# Out:
# ProductId  ProductName
# 92         Eggs - Retail                                               0.505925
# 491        Electricity - Retail                                        0.513580
# 181        Cabbage - Retail                                            1.723395
# 185        Salt - Retail                                               2.048213
# 173        Onions - Retail                                             2.141539
# 233        Cucumbers (greenhouse) - Retail                             2.206807
# 83         Potatoes - Retail                                           2.297231
# 229        Apples (red) - Retail                                       2.392193
# 384        Bread (pita) - Retail                                       2.404545
# 304        Transport (public) - Retail                                 2.468031
# 212        Peas (green, dry) - Retail                                  2.900029
# ...

# %%
average_price_df.sort_values('ProductName')
# Out:
#                                                                    Price
# ProductId ProductName
# 229       Apples (red) - Retail                                 2.392193
# 345       Apples - Retail                                       3.885039
# 254       Bananas - Retail                                      8.224784
# 66        Beans (white) - Retail                                9.572830
# 124       Bread (common) - Retail                               4.463293
# 384       Bread (pita) - Retail                                 2.404545
# 258       Bulgur - Retail                                       3.516712
# 181       Cabbage - Retail                                      1.723395
# 231       Cauliflower - Retail                                  3.274868
# 414       Cheese - Retail                                      25.522875
# 244       Chickpeas - Retail                                   10.347860
# 502       Cocoa (powder) - Retail                              43.802339
# ...

# %%
average_price_sorted_by_product_name = average_price.sort_values('ProductName')

# %% [markdown]
# # * Đề xuất:
# ### - Có thể phân tích mức giá trung bình của từng sản phẩm theo từng năm
# ### - Có thể phân tích được nơi mà các sản phẩm được sản xuất
# ### - Có thể sắp xếp mức giá của các món hàng từ thấp đến cao hoặc ngược lại
# ### - Có thể biết được giá của các mặt hàng có tăng lên hay giảm đi qua từng năm hay không
