# %% [markdown]
# # Classification (Thuật toán phân loại)

# %% [raw]
# Trong học máy (ML, Machine Learning), bài toán phân loại (classification) sẽ tìm ra các điều kiện biên cho mỗi nhóm từ tập dữ liệu, rồi sau đó sẽ dự đoán và phân loại dữ liệu thành các nhóm.

# %% [raw]
# Ví dụ:
# - Phân loại email nào là spam hay không
# - Nhận dạng chữ viết tay
# - Nhận dạng người

# %% [markdown]
# ## <span style="color:blue">Các loại bài toán phân loại</span>

# %% [raw]
# Các bài toán phân loại có thể chia ra làm 4 loại
# - Binary Classification (phân loại nhị phân)
# - Multi-Class Classification (phân loại nhiều lớp)
# - Multi-Label Classification (phân loại nhiều nhãn)
# - Imbalanced Classification (phân loại không cân bằng)

# %% [raw]
# Không có thuật toán phân loại nào có thể áp dụng cho mọi loại bài toán. Tùy bài toán cụ thể mà chọn thuật toán cho phù hợp.
#
# Khó có thuật toán phân loại nào có thể cho ra kết quả chính xác hoàn toàn.

# %% [markdown]
# ### <span style="color:red">Binary Classification</span>

# %% [raw]
# Bài toán phân loại nhị phân chia dữ liệu thành 2 nhóm.
#
# Ví dụ:
# - Phân loại email spam (spam - not spam)
# - Phân loại tin giả (fake - not fake)
# - Phân loại khối u (lành tính - ác tính)
#
# Một nhóm được gọi là 'bình thường' (normal), nhóm còn lại được gọi là 'dị thường' (abnormal).

# %% [raw]
# Các thuật toán có thể sử dụng cho phân loại nhị phân:
# - Logistic Regression
# - k-Nearest Neighbors (kNN)
# - Decision Trees
# - Support Vector Machine
# - Naive Bayes

# %%
#Demo 1
# example of binary classification task
from numpy import where #Lọc dữ liệu
from collections import Counter #Đếm dữ liệu
from sklearn.datasets import make_blobs #tạo dữ liệu phân nhóm ngẫu nhiên
from matplotlib import pyplot
import seaborn as sns

# define dataset
X, Y = make_blobs(n_samples=200, centers=2, random_state=3)
# summarize dataset shape
print(X.shape, Y.shape)
# summarize observations by class label
counter = Counter(Y)
print(counter)
# Out:
# (200, 2) (200,)
# Counter({0: 100, 1: 100})

# %%
sns.scatterplot(x=X[:,0], y=X[:,1], hue=Y);

# %%
# summarize first few examples
for i in range(10):
    print(X[i], Y[i])
# plot the dataset and color the by class label
for label, _ in counter.items():
    row_ix = where(Y == label)[0]
    pyplot.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.show()
# Out:
# [0.88819599 4.41112448] 0
# [0.36754716 3.42549161] 0
# [-4.21069087 -1.25739072] 1
# [0.585068   3.62268619] 0
# [-2.16225458  0.54281438] 1
# [-3.83108938  1.84312571] 1
# [2.2494291  4.31194285] 0
# [1.89024377 2.86941982] 0
# [0.69437336 4.31408682] 0
# [0.92072045 3.63576867] 0

# %% [markdown]
# ### <span style="color:red">Multi-Class Classification</span>

# %% [raw]
# Bài toán phân loại đa lớp chia dữ liệu thành nhiều hơn 2 lớp.
# Ví dụ:
# - Phân loại khuôn mặt (Á, Âu, Ả rập, Phi, etc)
# - Phân loại đối tượng giao thông (người đi bộ, xe đạp, xe máy, car)
# - Nhận dạng chữ viết (các chữ cái, dấu)

# %% [raw]
# Các thuật toán có thể sử dụng cho phân loại đa lớp:
# - k-Nearest Neighbors (kNN)
# - Decision Trees
# - Naive Bayes
# - Random Forest
# - Gradient Boosting
#
# Một số thuật toán dành cho phân loại nhị phân như 'Logistic Regression' và 'Support Vector Machine' có thể dùng cho phân loại đa lớp sử dụng một số phương thức thích hợp

# %%
#Demo 2
# example of multi-class classification task
from numpy import where
from collections import Counter
from sklearn.datasets import make_blobs
from matplotlib import pyplot
# define dataset
X, Y = make_blobs(n_samples=600, centers=3, random_state=3)
# summarize dataset shape
print(X.shape, Y.shape)
# summarize observations by class label
counter = Counter(Y)
print(counter)
sns.scatterplot(x=X[:,0], y=X[:,1], hue=Y);
# Out:
# (600, 2) (600,)
# Counter({1: 200, 0: 200, 2: 200})

# %% [markdown]
# ### <span style="color:red">Multi-Label Classification</span>

# %% [raw]
# Bài toán phân loại đa nhãn chia dữ liệu thành nhiều hơn 2 nhóm và mỗi đối tượng có thể nằm trong 1 hoặc nhiều hơn 1 nhóm
#
# Ví dụ:
# - Phân loại thể loại phim (hành động, trinh thám, kinh dị, ...). Một bộ phim có thể thuộc nhiều thể loại.

# %% [raw]
# Một số thuật toán được chỉnh sửa lại để giải các bài toán phân loại đa nhãn:
# - Multi-label Decision Trees
# - Multi-label Random Forests
# - Multi-label Gradient Boosting

# %%
#Demo 3
# example of multi-class classification task
from numpy import where
from collections import Counter
from sklearn.datasets import make_blobs
from matplotlib import pyplot
# define dataset
X, y = make_blobs(n_samples=600, centers=2, random_state=3, cluster_std = 3.0)
# summarize dataset shape
print(X.shape, y.shape)
# summarize observations by class label
counter = Counter(y)
print(counter)
# summarize first few examples
for i in range(10):
	print(X[i], y[i])
# plot the dataset and color the by class label
for label, _ in counter.items():
	row_ix = where(y == label)[0]
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.show()
# Out:
# (600, 2) (600,)
# Counter({0: 300, 1: 300})
# [3.05783891 2.15444813] 0
# [ 6.17438772 -2.91468776] 0
# [-8.70099358 -0.10684484] 1
# [-2.5556782   1.18884027] 1
# [2.85818931 1.64921963] 0
# [-7.12810008 -4.99432849] 1
# [-3.70814785  4.26387122] 1
# [-6.44923964  2.95635605] 1
# [-0.69563883 -1.92425992] 0
# [-4.64455272  4.45273766] 0

# %% [markdown]
# ### <span style="color:red">Imbalanced Classification</span>

# %% [raw]
# Bài toán phân loại không cân bằng chia dữ liệu thành nhiều nhóm và số lượng đối tượng nằm trong các nhóm không đồng đều.
#
# Ví dụ:
# - Phân loại khách hàng VIP trong tập khách hàng
# - Loại bỏ giá trị ngoại lai
# - Sàng lọc gia súc bị dị tật hoặc kém phát triển
#
# Số đông sẽ thuộc về nhóm normal, còn số ít sẽ thuộc nhóm abnormal.

# %% [raw]
# Một số thuật toán để giải các bài toán phân loại không đồng đều:
# - Cost-sensitive Logistic Regression.
# - Cost-sensitive Decision Trees.
# - Cost-sensitive Support Vector Machines.

# %%
#Demo 4
# example of an imbalanced binary classification task
from numpy import where
from collections import Counter
from sklearn.datasets import make_classification
from matplotlib import pyplot
# define dataset
X, y = make_classification(n_samples=1000, n_features=2, n_informative=2, n_redundant=0, n_classes=2, n_clusters_per_class=1, weights=[0.99,0.01], random_state=1)
# summarize dataset shape
print(X.shape, y.shape)
# summarize observations by class label
counter = Counter(y)
print(counter)
# summarize first few examples
for i in range(10):
	print(X[i], y[i])
# plot the dataset and color the by class label
for label, _ in counter.items():
	row_ix = where(y == label)[0]
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.show()
# Out:
# (1000, 2) (1000,)
# Counter({0: 983, 1: 17})
# [0.86924745 1.18613612] 0
# [1.55110839 1.81032905] 0
# [1.29361936 1.01094607] 0
# [1.11988947 1.63251786] 0
# [1.04235568 1.12152929] 0
# [1.18114858 0.92397607] 0
# [1.1365562  1.17652556] 0
# [0.46291729 0.72924998] 0
# [0.18315826 1.07141766] 0
# [0.32411648 0.53515376] 0

# %% [markdown]
# ## <span style="color:blue">Một số thuật toán phân loại cơ bản</span>

# %% [markdown]
# ### <span style="color:red">Logistic Regression</span>

# %% [raw]
# Thuật toán của Logistic Regression vẫn là hồi quy. Nhưng phương trình giả thiết là hàm Sigmoid

# %% [markdown]
# ![image.png](attachment:faa43817-273a-4ca8-b2c6-3157048f95de.png)

# %% [raw]
# Hàm này thỏa mãn 2 điều kiện để sử dụng trong logistic regression là:
# - Hàm liên tục và luôn đưa ra giá trị trong khoảng (0, 1) (phù hợp để phân nhóm)
# - Có đạo hàm tại mọi điểm nên có thể dùng gradient descent

# %% [raw]
# Demo 1

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# from numpy import where
# from collections import Counter
from sklearn.datasets import make_blobs
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix

# Tạo dataset
X, Y = make_blobs(n_samples=600, centers=2, random_state=3, cluster_std=2)

# sns.scatterplot(X[:,0], X[:,1])
# plt.show()

sns.scatterplot(x=X[:,0], y=X[:,1], hue=Y)
plt.show()

# %%
import sklearn.model_selection as model_selection
#Chia bộ dữ liệu thành 2 phần train và test
X_train, X_test, Y_train, Y_test = model_selection.train_test_split(X,Y, train_size=0.6)
# X_train

# %%
# instantiate the model (using the default parameters)
# logreg = LogisticRegression(random_state=16)
logreg = LogisticRegression()

# fit the model with data
logreg.fit(X_train, Y_train)

#Dự đoán với giá trị đầu vào là X_test
Y_pred = logreg.predict(X_test)

sns.scatterplot(x=X_train[:,0], y=X_train[:,1], hue=Y_train)
plt.show()

sns.scatterplot(x=X_test[:,0], y=X_test[:,1], hue=Y_test)
plt.show()

sns.scatterplot(x=X_test[:,0], y=X_test[:,1], hue=Y_pred)
plt.show()

# %%
#Predict giá trị
import numpy as np
x_ = [5, -2]
x_ = np.array(x_).reshape(1, -1)
# x_
y_ = logreg.predict(x_)
print(y_)
# Biểu diễn điểm này trên đồ thị
sns.scatterplot(x=X_test[:,0], y=X_test[:,1], hue=Y_test)
sns.scatterplot(x=x_[:,0], y=x_[:,1], color='r')
plt.show()
# Out:
# [0]

# %%
#Evaluate model
conf_m = confusion_matrix(Y_test, Y_pred)
report = classification_report(Y_test, Y_pred)

print('conf_m:', conf_m, sep='\n', end='\n\n')
sns.heatmap(conf_m)
plt.show()

print('report:', report, sep='\n')
# Out:
# conf_m:
# [[109   8]
#  [  6 117]]
# report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94       117
#            1       0.94      0.95      0.94       123
#
#     accuracy                           0.94       240
#    macro avg       0.94      0.94      0.94       240
# weighted avg       0.94      0.94      0.94       240

# %% [raw]
# Demo 2: Phân loại hoa IRIS

# %%
import pandas as pd

# %% [markdown]
# ![image.png](attachment:1658c8ff-2289-4873-b760-92d0f3b20047.png)

# %%
dat2 = pd.read_csv('IRIS.csv')
dat2
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
dat2.info()

# %%
dat2['species'].unique()

# %% [raw]
# Lọc lấy chỉ 2 loài hoa 'Iris-setosa' và 'Iris-versicolor'. Chia dữ liệu thành 2 bộ dữ liệu train và test. Sau đó học từ bộ dữ liệu train. Đánh giá việc học qua bộ dữ liệu test. Vẽ đồ thị.

# %%
aa = ['Iris-setosa', 'Iris-versicolor']
dat22 = dat2.query('species in @aa')
dat22

# %%
from sklearn.linear_model import LogisticRegression

logreg = LogisticRegression(multi_class='auto')

dat22.loc[dat22['species']=='Iris-setosa','species'] = 0
dat22.loc[dat22['species']=='Iris-versicolor','species'] = 1
dat22 = dat22.astype({'species':'int'})
dat22

# %%
dat22['species'].unique()

# %%
#Đặt X và Y
X = dat22.iloc[:,0:4]
Y = dat22.iloc[:,4]

# %%
#Quá trình học
logreg.fit(X, Y)

# %%
#Dự đoán với giá trị X ban đầu
Y_ = logreg.predict(X)

# %%
#Evaluate model
conf_m = confusion_matrix(Y, Y_)
report = classification_report(Y, Y_)

print('conf_m:', conf_m, sep='\n', end='\n\n')
sns.heatmap(conf_m)
plt.show()

print('report:', report, sep='\n')

# %% [raw]
# Demo 3: Vẫn dùng dữ liệu trên, chia dữ liệu thành 2 bộ dữ liệu train và test. Phân loại ra 3 loài hoa sử dụng Logistic Regression từ bộ dữ liệu train. Đánh giá việc học qua bộ dữ liệu test. Vẽ đồ thị.

# %%
from sklearn.model_selection import train_test_split

X = dat2.drop(columns='species',axis=1)
Y = dat2['species']

X_train,X_test,Y_train,Y_test = train_test_split(X, Y, test_size=0.3) # 30% dữ liệu là test
print(X_train.shape)  # 120 records out of 150 will be the training data
print(X_test.shape)   #  30 records out of 150 will be the testing  data

# %%
import time
#Tạo đối tượng model
logreg = LogisticRegression()

start = time.time() #Thời gian bắt đầu tính toán

#Train
logreg.fit(X_train, Y_train)
print('Đã học xong trong:', time.time()-start, ' s')

#Predict
Y_pred = logreg.predict(X_test)
print('Đã dự đoán xong')

# %%
#Evaluate model
from sklearn.metrics import classification_report, confusion_matrix
conf_m = confusion_matrix(Y_test, Y_pred)
report = classification_report(Y_test, Y_pred)

print('conf_m:', conf_m, sep='\n', end='\n\n')
sns.heatmap(conf_m)
plt.show()

print('report:', report, sep='\n')

# %%
sns.pairplot(data=dat2, hue='species');

# %%
test = pd.concat([X_test, Y_test], axis=1) #Tạo df 'test'

#biến đổi np.array thành df có index = index của df 'test'
Y_pred_ = pd.DataFrame(Y_pred, index=test.index, columns = ['species']) 
pred = pd.concat([X_test, Y_pred_], axis=1) #Tạo df 'pred'

# %%
fig, ax = plt.subplots(1,2, figsize=(10, 5))
sns.scatterplot(data=test, x='petal_length', y='petal_width', hue='species', s=50, ax=ax[0])\
    .set(title='TEST');
sns.scatterplot(data=pred, x='petal_length', y='petal_width', hue='species', s=50, ax=ax[1])\
    .set(title='PRED');
plt.tight_layout();
plt.show()

# %%
#Trực quan hóa sử dụng parallel_coordinates (biểu đồ bình phong)
from pandas.plotting import parallel_coordinates

fig, ax = plt.subplots(2,1, figsize=(10, 10))

parallel_coordinates(test, "species", ax=ax[0], colormap = 'Accent')
ax[0].set_title('TEST')
ax[0].set_xlabel('Features'); ax[0].set_ylabel('Features values')

parallel_coordinates(pred, "species", ax=ax[1], colormap = 'Accent')
ax[1].set_title('PRED')
ax[1].set_xlabel('Features'); ax[1].set_ylabel('Features values')

plt.tight_layout();
plt.show()

# %%
#Trực quan hóa sử dụng Radviz
from pandas.plotting import radviz

fig, ax = plt.subplots(1,2, figsize=(13, 5))
# plt.figure(figsize=(15,10))
radviz(test[test['species'] != 'Iris-setosa'], "species", ax=ax[0], colormap = 'tab10')
ax[0].set_title('TEST')

radviz(pred[pred['species'] != 'Iris-setosa'], "species", ax=ax[1], colormap = 'tab10')
ax[1].set_title('PRED')

plt.tight_layout();
plt.show()

# %% [markdown]
# ### <span style="color:red">K-Nearest Neighbors</span>

# %% [raw]
# Tính khoảng cách (Euclid,...) từ điểm dữ liệu cần xem xét tới 1 số lượng điểm lân cận (hàng xóm) đã biết gần nhất, để từ đó phân loại xem điểm dữ liệu mới thuộc nhóm nào.
#
# Ưu điểm: Đơn giản, chịu nhiễu tốt, hiệu quả cao khi data lớn
# Nhược điểm: Yêu cầu khả năng tính toán của máy phải tốt

# %% [markdown]
# ![image.png](attachment:bcf889f5-5fe6-4b8e-82c2-f9e71645970b.png)![image.png](attachment:01872e5d-c8d4-4657-b3b2-3ce1ac2f91da.png)

# %%
#Thư viện
import time
from sklearn.neighbors import KNeighborsClassifier

#Tạo model
knn = KNeighborsClassifier(n_neighbors=5) #Test với n=9


start = time.time()

#fit, học, train
knn.fit(X_train,Y_train)

print('Đã học xong trong:', time.time()-start, ' s')

#dự đoán
y_pred = knn.predict(X_test)

# %%
#Evaluate model
conf_m = confusion_matrix(Y_test, Y_pred)
report = classification_report(Y_test, Y_pred)

print('conf_m:', conf_m, sep='\n', end='\n\n')
sns.heatmap(conf_m)
plt.show()

print('report:', report, sep='\n')

# %%
test = pd.concat([X_test, Y_test], axis=1) #Tạo df 'test'
#biến đổi np.array thành df có index = index của df 'test'
Y_pred = pd.DataFrame(Y_pred, index=test.index, columns = ['species']) 
pred = pd.concat([X_test, Y_pred], axis=1) #Tạo df 'pred'

# %%
sns.pairplot(data=test, hue='species')
sns.pairplot(data=pred, hue='species')

# %%
fig, ax = plt.subplots(1,2, figsize=(10, 5))
sns.scatterplot(data=test, x='petal_length', y='petal_width', hue='species', s=50, ax=ax[0])\
    .set(title='TEST');
sns.scatterplot(data=pred, x='petal_length', y='petal_width', hue='species', s=50, ax=ax[1])\
    .set(title='PRED');
plt.tight_layout();
plt.show()

# %%
#Trực quan hóa sử dụng parallel_coordinates (biểu đồ bình phong)
from pandas.plotting import parallel_coordinates

fig, ax = plt.subplots(2,1, figsize=(10, 10))

parallel_coordinates(test, "species", ax=ax[0], colormap = 'tab10')
ax[0].set_title('TEST')
ax[0].set_xlabel('Features'); ax[0].set_ylabel('Features values')

parallel_coordinates(pred, "species", ax=ax[1], colormap = 'tab10')
ax[1].set_title('PRED')
ax[1].set_xlabel('Features'); ax[1].set_ylabel('Features values')

plt.tight_layout();
plt.show()

# %%
#Trực quan hóa sử dụng Radviz
from pandas.plotting import radviz

fig, ax = plt.subplots(1,2, figsize=(13, 5))
# plt.figure(figsize=(15,10))
radviz(test[test['species'] != 'Iris-setosa'], "species", ax=ax[0], colormap = 'tab10')
ax[0].set_title('TEST')

radviz(pred[pred['species'] != 'Iris-setosa'], "species", ax=ax[1], colormap = 'tab10')
ax[1].set_title('PRED')

plt.tight_layout();
plt.show()

# %% [markdown]
# ### <span style="color:red">Decision Tree</span>

# %% [raw]
# Thuật toán sẽ thử các điều kiện, từ đó chia thành các nhánh và nhánh nhỏ hơn nữa. Từ đó đưa ra được kết luận về dữ liệu.
#
# Ưu điểm: Dễ
# Nhược điểm: Khả năng cao bị overfitting

# %% [markdown]
# ![image.png](attachment:7ce36dcb-9c62-4779-a62a-c8b3970bd745.png)

# %%
#Thư viện
from sklearn.tree import DecisionTreeClassifier

#Tạo model
dec_tree = DecisionTreeClassifier()

#fit, train
start = time.time()
dec_tree.fit(X_train,Y_train)
print('Đã học xong trong:', time.time()-start, ' s')

#dự đoán
y_pred = dec_tree.predict(X_test)

# %%
#Tạo bảng df để trực quan hóa
test = pd.concat([X_test, Y_test], axis=1)
Y_pred = pd.DataFrame(Y_pred, index=test.index, columns = ['species'])
pred = pd.concat([X_test, Y_pred], axis=1)

# %%
sns.pairplot(data=test, hue='species')
sns.pairplot(data=pred, hue='species')

# %%
#Evaluate model
conf_m = confusion_matrix(Y_test, Y_pred)
report = classification_report(Y_test, Y_pred)

print('conf_m:', conf_m, sep='\n', end='\n\n')
sns.heatmap(conf_m)
plt.show()

print('report:', report, sep='\n')

# %%
fig, ax = plt.subplots(1,2, figsize=(10, 5))
sns.scatterplot(data=test, x='petal_length', y='petal_width', hue='species', s=50, ax=ax[0])\
    .set(title='TEST');
sns.scatterplot(data=pred, x='petal_length', y='petal_width', hue='species', s=50, ax=ax[1])\
    .set(title='PRED');
plt.tight_layout();
plt.show()

# %%
#Trực quan hóa sử dụng parallel_coordinates
from pandas.plotting import parallel_coordinates
fig, ax = plt.subplots(2,1, figsize=(10, 10))
# plt.figure(figsize=(15,10))
parallel_coordinates(test, "species", ax=ax[0], colormap = 'tab10')
ax[0].set_title('TEST')
ax[0].set_xlabel('Features'); ax[0].set_ylabel('Features values')
# plt.legend(loc=1, prop={'size': 15}, frameon=True,shadow=True, facecolor="white", edgecolor="black")

parallel_coordinates(pred, "species", ax=ax[1], colormap = 'tab10')
ax[1].set_title('PRED')
ax[1].set_xlabel('Features'); ax[1].set_ylabel('Features values')

plt.tight_layout();
plt.show()

# %%
#Trực quan hóa sử dụng Radviz
from pandas.plotting import radviz

fig, ax = plt.subplots(1,2, figsize=(13, 5))
# plt.figure(figsize=(15,10))
radviz(test[test['species'] != 'Iris-setosa'], "species", ax=ax[0], colormap = 'tab10')
ax[0].set_title('TEST')

radviz(pred[pred['species'] != 'Iris-setosa'], "species", ax=ax[1], colormap = 'tab10')
ax[1].set_title('PRED')

plt.tight_layout();
plt.show()

# %% [markdown]
# ### <span style="color:red">Support Vector Machine</span>

# %% [raw]
# Thuật toán tìm ra đường phân chia nằm cách đều nhất, xa nhất các lớp.
#
# Ưu điểm:
# - Rất tốt nếu các lớp phân chia rõ ràng
# - Tốt khi multi-class (multi-feature, multi-dimension)
# - Yêu cầu phần cứng thấp
# Nhược điểm:
# - Nhạy cảm với nhiễu
# - Chậm

# %% [markdown]
# <img src="attachment:6487cd5f-2d0e-4fd3-a9b6-679bd0381ede.png" width="500"><img src="attachment:27b2cac0-9982-4f84-931b-921625d87dac.png" width="500">

# %%
#Thư viện
from sklearn.svm import SVC

#Tạo model
svc = SVC()

#fit
start = time.time()
svc.fit(X_train,Y_train)
print('Đã tính toán xong trong: ', time.time()-start, ' s')

#dự đoán
Y_pred = svc.predict(X_test)

# %%
#Tạo thành dataframe
test = pd.concat([X_test, Y_test], axis=1)
Y_pred = pd.DataFrame(Y_pred, index=test.index, columns = ['species'])
pred = pd.concat([X_test, Y_pred], axis=1)

# %%
#Evaluate model
conf_m = confusion_matrix(Y_test, Y_pred)
report = classification_report(Y_test, Y_pred)

print('conf_m:', conf_m, sep='\n', end='\n\n')
sns.heatmap(conf_m)
plt.show()

print('report:', report, sep='\n')

# %%
sns.pairplot(data=test, hue='species')
sns.pairplot(data=pred, hue='species')

# %%
fig, ax = plt.subplots(1,2, figsize=(10, 5))
sns.scatterplot(data=test, x='petal_length', y='petal_width', hue='species', s=50, ax=ax[0])\
    .set(title='TEST');
sns.scatterplot(data=pred, x='petal_length', y='petal_width', hue='species', s=50, ax=ax[1])\
    .set(title='PRED');
plt.tight_layout();
plt.show()

# %%
#Trực quan hóa sử dụng parallel_coordinates
from pandas.plotting import parallel_coordinates
fig, ax = plt.subplots(2,1, figsize=(10, 10))
# plt.figure(figsize=(15,10))
parallel_coordinates(test, "species", ax=ax[0], colormap = 'tab10')
ax[0].set_title('TEST')
ax[0].set_xlabel('Features'); ax[0].set_ylabel('Features values')
# plt.legend(loc=1, prop={'size': 15}, frameon=True,shadow=True, facecolor="white", edgecolor="black")

parallel_coordinates(pred, "species", ax=ax[1], colormap = 'tab10')
ax[1].set_title('PRED')
ax[1].set_xlabel('Features'); ax[1].set_ylabel('Features values')

plt.tight_layout();
plt.show()

# %%
#Trực quan hóa sử dụng Radviz
from pandas.plotting import radviz

fig, ax = plt.subplots(1,2, figsize=(13, 5))
# plt.figure(figsize=(15,10))
radviz(test[test['species'] != 'Iris-setosa'], "species", ax=ax[0], colormap = 'tab10')
ax[0].set_title('TEST')

radviz(pred[pred['species'] != 'Iris-setosa'], "species", ax=ax[1], colormap = 'tab10')
ax[1].set_title('PRED')

plt.tight_layout();
plt.show()

# %% [markdown]
# ### <span style="color:red">Naive Bayes (Bayes ngây thơ)</span>

# %% [raw]
# Thuật toán giả thiết rằng các đặc trưng là độc lập, từ đó dựa vào công thức tính xác suất để chia nhóm
#
# Ưu điểm:
# - Với giả thiết các đặc trưng là độc lập thì phương pháp rất hiệu quả (một cách bất ngờ)
# - Tốt với bài toán imbalanced
# - Nhanh
# Nhược điểm:
# - Trên thực tế, các đặc trưng có thể ko phải là độc lập

# %%
#Thư viện
from sklearn.naive_bayes import GaussianNB

#Tạo model
nb = GaussianNB()

#fit
start = time.time()
nb.fit(X_train,Y_train)
print('Đã tính toán xong trong: ', time.time()-start, ' s')

#dự đoán
Y_pred = nb.predict(X_test)

# %%
test = pd.concat([X_test, Y_test], axis=1)
Y_pred = pd.DataFrame(Y_pred, index=test.index, columns = ['species'])
pred = pd.concat([X_test, Y_pred], axis=1)

# %%
sns.pairplot(data=test, hue='species')
sns.pairplot(data=pred, hue='species')

# %%
#Evaluate model
conf_m = confusion_matrix(Y_test, Y_pred)
report = classification_report(Y_test, Y_pred)

print('conf_m:', conf_m, sep='\n', end='\n\n')
sns.heatmap(conf_m)
plt.show()

print('report:', report, sep='\n')

# %%
fig, ax = plt.subplots(1,2, figsize=(10, 5))
sns.scatterplot(data=test, x='petal_length', y='petal_width', hue='species', s=50, ax=ax[0])\
    .set(title='TEST');
sns.scatterplot(data=pred, x='petal_length', y='petal_width', hue='species', s=50, ax=ax[1])\
    .set(title='PRED');
plt.tight_layout();
plt.show()

# %%
#Trực quan hóa sử dụng parallel_coordinates
from pandas.plotting import parallel_coordinates
fig, ax = plt.subplots(2,1, figsize=(10, 10))
# plt.figure(figsize=(15,10))
parallel_coordinates(test, "species", ax=ax[0], colormap = 'tab10')
ax[0].set_title('TEST')
ax[0].set_xlabel('Features'); ax[0].set_ylabel('Features values')
# plt.legend(loc=1, prop={'size': 15}, frameon=True,shadow=True, facecolor="white", edgecolor="black")

parallel_coordinates(pred, "species", ax=ax[1], colormap = 'tab10')
ax[1].set_title('PRED')
ax[1].set_xlabel('Features'); ax[1].set_ylabel('Features values')

plt.tight_layout();
plt.show()

# %%
#Trực quan hóa sử dụng Radviz
from pandas.plotting import radviz

fig, ax = plt.subplots(1,2, figsize=(13, 5))
# plt.figure(figsize=(15,10))
radviz(test[test['species'] != 'Iris-setosa'], "species", ax=ax[0], colormap = 'tab10')
ax[0].set_title('TEST')

radviz(pred[pred['species'] != 'Iris-setosa'], "species", ax=ax[1], colormap = 'tab10')
ax[1].set_title('PRED')

plt.tight_layout();
plt.show()

# %% [markdown]
# ## Tổng kết

# %%
method = ['Logistic Regression', 'kNN', 'Decision Tree', 'SVM', 'Naive Bayes']
time = [0.15, 0.004, 0.0042, 0.0050, 0.0050]
accuracy = [0.96, 0.96, 0.93, 0.96, 0.96]

# 0.13 0.04 0.04 0.05 0.04
# 0.96 0.98 0.98 0.98 0.96

# %% [markdown]
# # Thực hành

# %% [raw]
# Bộ dữ liệu về điện thoại bao gồm các thông số kỹ thuật và mức giá của các loại điện thoại di động. Bao gồm dữ liệu train và dữ liệu test.
#
# Xây dựng model dựa trên các thuật toán đã học với bộ dữ liệu train
# Kiểm tra với bộ dữ liệu test
#
# Vẽ hình

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('mobile train.csv')
train

# %%
train.info()

# %%
train['price_range'].unique()

# %%
sns.pairplot(data=train)

# %%
test = pd.read_csv("mobile test.csv")
test

# %%
test.info()

# %%
# Chia bộ dữ liệu thành 2 bộ nhỏ hơn là train_ và test_
from sklearn.feature_selection import train_test_split

X =

# %% [markdown]
# ## Logistic Regression

# %% [markdown]
# ## K-NN

# %% [markdown]
# ## Decision Tree

# %% [markdown]
# ## SVM

# %% [markdown]
# ## Naive Bayes

# %%
import time
import warnings

import numpy as np
import matplotlib.pyplot as plt

from sklearn import cluster, datasets, mixture
from sklearn.neighbors import kneighbors_graph
from sklearn.preprocessing import StandardScaler
from itertools import cycle, islice
warnings.filterwarnings('ignore')

np.random.seed(0)

# ============
# Generate datasets. We choose the size big enough to see the scalability
# of the algorithms, but not too big to avoid too long running times
# ============
n_samples = 500
noisy_circles = datasets.make_circles(n_samples=n_samples, factor=0.5, noise=0.05)
noisy_moons = datasets.make_moons(n_samples=n_samples, noise=0.05)
blobs = datasets.make_blobs(n_samples=n_samples, random_state=8)
no_structure = np.random.rand(n_samples, 2), None

# Anisotropicly distributed data
random_state = 170
X, y = datasets.make_blobs(n_samples=n_samples, random_state=random_state)
transformation = [[0.6, -0.6], [-0.4, 0.8]]
X_aniso = np.dot(X, transformation)
aniso = (X_aniso, y)

# blobs with varied variances
varied = datasets.make_blobs(
    n_samples=n_samples, cluster_std=[1.0, 2.5, 0.5], random_state=random_state
)

# ============
# Set up cluster parameters
# ============
plt.figure(figsize=(9 * 2 + 3, 13))
plt.subplots_adjust(
    left=0.02, right=0.98, bottom=0.001, top=0.95, wspace=0.05, hspace=0.01
)

plot_num = 1

default_base = {
    "quantile": 0.3,
    "eps": 0.3,
    "damping": 0.9,
    "preference": -200,
    "n_neighbors": 3,
    "n_clusters": 3,
    "min_samples": 7,
    "xi": 0.05,
    "min_cluster_size": 0.1,
}

datasets_name = ['blobs', 'varied', 'aniso', 'noisy_circles', 'noisy_moons', 'no_structure']

datasets = [
    (blobs, {"min_samples": 7, "xi": 0.1, "min_cluster_size": 0.2}),
    (
        varied,
        {
            "eps": 0.18,
            "n_neighbors": 2,
            "min_samples": 7,
            "xi": 0.01,
            "min_cluster_size": 0.2,
        },
    ),
    (
        aniso,
        {
            "eps": 0.15,
            "n_neighbors": 2,
            "min_samples": 7,
            "xi": 0.1,
            "min_cluster_size": 0.2,
        },
    ),
    (
        noisy_circles,
        {
            "damping": 0.77,
            "preference": -240,
            "quantile": 0.2,
            "n_clusters": 2,
            "min_samples": 7,
            "xi": 0.08,
        },
    ),
    (
        noisy_moons,
        {
            "damping": 0.75,
            "preference": -220,
            "n_clusters": 2,
            "min_samples": 7,
            "xi": 0.1,
        },
    ),
    (no_structure, {}),
]

for i_dataset, (dataset, algo_params) in enumerate(datasets):
    # update parameters with dataset-specific values
    params = default_base.copy()
    params.update(algo_params)

    X, y = dataset

    # normalize dataset for easier parameter selection
    X = StandardScaler().fit_transform(X)

    # estimate bandwidth for mean shift
    bandwidth = cluster.estimate_bandwidth(X, quantile=params["quantile"])
# connectivity matrix for structured Ward
    connectivity = kneighbors_graph(
        X, n_neighbors=params["n_neighbors"], include_self=False
    )
    # make connectivity symmetric
    connectivity = 0.5 * (connectivity + connectivity.T)

    # ============
    # Create cluster objects
    # ============
    ms = cluster.MeanShift(bandwidth=bandwidth, bin_seeding=True)
    two_means = cluster.MiniBatchKMeans(n_clusters=params["n_clusters"])
    ward = cluster.AgglomerativeClustering(
        n_clusters=params["n_clusters"], linkage="ward", connectivity=connectivity
    )
    spectral = cluster.SpectralClustering(
        n_clusters=params["n_clusters"],
        eigen_solver="arpack",
        affinity="nearest_neighbors",
    )
    dbscan = cluster.DBSCAN(eps=params["eps"])
    optics = cluster.OPTICS(
        min_samples=params["min_samples"],
        xi=params["xi"],
        min_cluster_size=params["min_cluster_size"],
    )
    affinity_propagation = cluster.AffinityPropagation(
        damping=params["damping"], preference=params["preference"], random_state=0
    )
    average_linkage = cluster.AgglomerativeClustering(
        linkage="average",
        affinity="cityblock",
        n_clusters=params["n_clusters"],
        connectivity=connectivity,
    )
    birch = cluster.Birch(n_clusters=params["n_clusters"])
    gmm = mixture.GaussianMixture(
        n_components=params["n_clusters"], covariance_type="full"
    )

    clustering_algorithms = (
        ("MiniBatch\nKMeans", two_means),
        ("Affinity\nPropagation", affinity_propagation),
        ("MeanShift", ms),
        ("Spectral\nClustering", spectral),
        ("Ward", ward),
        ("Agglomerative\nClustering", average_linkage),
        ("DBSCAN", dbscan),
        ("OPTICS", optics),
        ("BIRCH", birch),
        ("Gaussian\nMixture", gmm),
    )

    for name, algorithm in clustering_algorithms:
        t0 = time.time()

        # catch warnings related to kneighbors_graph
        with warnings.catch_warnings():
            warnings.filterwarnings(
                "ignore",
                message="the number of connected components of the "
                + "connectivity matrix is [0-9]{1,2}"
                + " > 1. Completing it to avoid stopping the tree early.",
                category=UserWarning,
            )
            warnings.filterwarnings(
                "ignore",
                message="Graph is not fully connected, spectral embedding"
                + " may not work as expected.",
                category=UserWarning,
            )
            algorithm.fit(X)

        t1 = time.time()
        if hasattr(algorithm, "labels_"):
            y_pred = algorithm.labels_.astype(int)
        else:
            y_pred = algorithm.predict(X)

        plt.subplot(len(datasets), len(clustering_algorithms), plot_num)
        if i_dataset == 0:
            plt.title(name, size=18)
        if name=="MiniBatch\nKMeans":
            plt.ylabel(datasets_name[i_dataset], fontsize=18.0)
        
        colors = np.array(
            list(
                islice(
                    cycle(
                        [
                            "#377eb8",
                            "#ff7f00",
                            "#4daf4a",
                            "#f781bf",
                            "#a65628",
                            "#984ea3",
                            "#999999",
                            "#e41a1c",
                            "#dede00",
                        ]
                    ),
                    int(max(y_pred) + 1),
                )
            )
        )
        # add black color for outliers (if any)
        colors = np.append(colors, ["#000000"])
        plt.scatter(X[:, 0], X[:, 1], s=10, color=colors[y_pred])

        plt.xlim(-2.5, 2.5)
        plt.ylim(-2.5, 2.5)
        plt.xticks(())
        plt.yticks(())
        plt.text(
            0.99,
            0.01,
            ("%.2fs" % (t1 - t0)).lstrip("0"),
            transform=plt.gca().transAxes,
            size=15,
            horizontalalignment="right",
        )
        plot_num += 1

plt.show()
