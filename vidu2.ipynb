# %%
# Khai báo thư viện
import pandas as pd
import numpy as np
print('Khai báo thư viện thành công')
# Out:
# Khai báo thư viện thành công

# %%
# Nhập dữ liệu
data = pd.read_csv('FoodPrice_in_Turkey.csv',
                   header=0, encoding = "ISO-8859-1")
print('*'*20, "Nhập dữ liệu thành công", '*'*20)
display(data)
# data2 = pd.read_csv('FoodPrice_in_Turkey.csv', header = 0, encoding = 'utf-8')
# display(data2)
# Out:
# ******************** Nhập dữ liệu thành công ********************
#                  Place  ProductId              ProductName  UmId UmName  \
# 0     National Average         52            Rice - Retail     5     KG
# 1     National Average         52            Rice - Retail     5     KG
# 2     National Average         52            Rice - Retail     5     KG
# 3     National Average         52            Rice - Retail     5     KG
# 4     National Average         52            Rice - Retail     5     KG
# ...                ...        ...                      ...   ...    ...
# 7376             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7377             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7378             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7379             Izmir        502  Cocoa (powder) - Retail     5     KG
# 7380             Izmir        502  Cocoa (powder) - Retail     5     KG
#
#       Month  Year    Price
# 0         5  2013   4.4920
# 1         6  2013   4.5786
# 2        11  2013   4.7865
# 3        12  2013   5.1337
# 4         1  2014   5.5099
# ...     ...   ...      ...
# 7376      8  2019  47.9040
# 7377      9  2019  49.1176
# 7378     10  2019  50.8347
# 7379     11  2019  51.7985
# 7380     12  2019  51.6071
#
# [7381 rows x 8 columns]

# %%
data.to_csv('second_time_FoodPrice.csv') #Khuyến cáo nên lưu ra file csv

# %%
data.info() #.info() method, hàm
# data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7381 entries, 0 to 7380
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Place        7381 non-null   object
#  1   ProductId    7381 non-null   int64
#  2   ProductName  7381 non-null   object
#  3   UmId         7381 non-null   int64
#  4   UmName       7381 non-null   object
#  5   Month        7381 non-null   int64
#  6   Year         7381 non-null   int64
#  7   Price        7381 non-null   float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 461.4+ KB

# %%
#Xác định số dòng và số cột của dữ liệu
print(data.shape) # shape là property, tính chất, thuộc tính
#Số cột
print(data.shape[0])
#Số hàng
print(data.shape[1])
# Out:
# (7381, 8)
# 7381
# 8

# %%
# Xác định tên các cột
data.columns
# Out:
# Index(['Place', 'ProductId', 'ProductName', 'UmId', 'UmName', 'Month', 'Year',
#        'Price'],
#       dtype='object')

# %% [markdown]
# ## Đổi tên cột

# %%
# Việt hóa tên các cột
# Đổi tên chỉ 1 cột xác định
# data.rename(columns = {'Place':'Địa điểm'}, inplace=True)

# Đổi tên chỉ 1 vài cột xác định
# data.rename(columns = {'ProductId':'Mã sản phẩm', 'ProductName':'Tên sản phẩm'}, inplace=True)
# data.rename(columns = {'UmId':'Số lượng', 'UmName':'Tên đơn vị'}, inplace=False) #Bảng data không thay đổi

# Đổi tên toàn bộ các cột (Yêu cầu liệt kê đầy đủ tên cột mới và theo đúng thứ tự)
data.columns = ['Địa điểm', 'Mã SP', 'Tên SP', 'Đơn vị', 'Tên đơn vị', 'Tháng', 'Năm', 'Giá'] #Phải đủ số lượng tên các cột

data
# Out:
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0     National Average     52            Rice - Retail       5         KG
# 1     National Average     52            Rice - Retail       5         KG
# 2     National Average     52            Rice - Retail       5         KG
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7376             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7377             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7378             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7379             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
#
#       Tháng   Năm      Giá
# 0         5  2013   4.4920
# 1         6  2013   4.5786
# 2        11  2013   4.7865
# 3        12  2013   5.1337
# 4         1  2014   5.5099
# ...     ...   ...      ...
# 7376      8  2019  47.9040
# 7377      9  2019  49.1176
# 7378     10  2019  50.8347
# 7379     11  2019  51.7985
# 7380     12  2019  51.6071
#
# [7381 rows x 8 columns]

# %% [markdown]
# ## Thêm cột vào bảng đã có

# %%
# Thêm cột mới vào sau cuối
data['tên cột mới'] = np.NaN
data
# Out:
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0     National Average     52            Rice - Retail       5         KG
# 1     National Average     52            Rice - Retail       5         KG
# 2     National Average     52            Rice - Retail       5         KG
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7376             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7377             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7378             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7379             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
#
#       Tháng   Năm      Giá  tên cột mới
# 0         5  2013   4.4920          NaN
# 1         6  2013   4.5786          NaN
# 2        11  2013   4.7865          NaN
# 3        12  2013   5.1337          NaN
# 4         1  2014   5.5099          NaN
# ...     ...   ...      ...          ...
# 7376      8  2019  47.9040          NaN
# 7377      9  2019  49.1176          NaN
# 7378     10  2019  50.8347          NaN
# 7379     11  2019  51.7985          NaN
# 7380     12  2019  51.6071          NaN
#
# [7381 rows x 9 columns]

# %%
# Chèn thêm cột 'Chiết khấu' vào sau cột 'Giá'
data.insert(8,'Chiết khấu (%)', 20)
display(data)
# data.info()
# Out:
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0     National Average     52            Rice - Retail       5         KG
# 1     National Average     52            Rice - Retail       5         KG
# 2     National Average     52            Rice - Retail       5         KG
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7376             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7377             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7378             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7379             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
#
#       Tháng   Năm      Giá  Chiết khấu (%)  tên cột mới
# 0         5  2013   4.4920              20          NaN
# 1         6  2013   4.5786              20          NaN
# 2        11  2013   4.7865              20          NaN
# 3        12  2013   5.1337              20          NaN
# 4         1  2014   5.5099              20          NaN
# ...     ...   ...      ...             ...          ...
# 7376      8  2019  47.9040              20          NaN
# 7377      9  2019  49.1176              20          NaN
# 7378     10  2019  50.8347              20          NaN
# 7379     11  2019  51.7985              20          NaN
# 7380     12  2019  51.6071              20          NaN
#
# [7381 rows x 10 columns]

# %%
# Thêm 1 cột tên là "số lượng" nằm trước cột Giá, giá trị toàn bộ là 50
data.insert(7,'Số lượng',50)
data
# Out:
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0     National Average     52            Rice - Retail       5         KG
# 1     National Average     52            Rice - Retail       5         KG
# 2     National Average     52            Rice - Retail       5         KG
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7376             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7377             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7378             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7379             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
#
#       Tháng   Năm  Số lượng      Giá  Chiết khấu (%)  tên cột mới
# 0         5  2013        50   4.4920              20          NaN
# 1         6  2013        50   4.5786              20          NaN
# 2        11  2013        50   4.7865              20          NaN
# 3        12  2013        50   5.1337              20          NaN
# 4         1  2014        50   5.5099              20          NaN
# ...     ...   ...       ...      ...             ...          ...
# 7376      8  2019        50  47.9040              20          NaN
# 7377      9  2019        50  49.1176              20          NaN
# 7378     10  2019        50  50.8347              20          NaN
# 7379     11  2019        50  51.7985              20          NaN
# 7380     12  2019        50  51.6071              20          NaN
#
# [7381 rows x 11 columns]

# %%
# Đổi tên "Tên cột mới" thành "Tổng" và có giá trị là giá*số lượng*(100%-chiết khấu)
# gợi ý: data['A'] = data[B]*C*(100-D)/100
data.rename(columns = {'tên cột mới':'tổng'}, inplace=True)
data['tổng'] = data['Giá'] * data['Số lượng'] * (100-data['Chiết khấu (%)'])/100
data
# Out:
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0     National Average     52            Rice - Retail       5         KG
# 1     National Average     52            Rice - Retail       5         KG
# 2     National Average     52            Rice - Retail       5         KG
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7376             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7377             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7378             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7379             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
#
#       Tháng   Năm  Số lượng      Giá  Chiết khấu (%)      tổng
# 0         5  2013        50   4.4920              20   179.680
# 1         6  2013        50   4.5786              20   183.144
# 2        11  2013        50   4.7865              20   191.460
# 3        12  2013        50   5.1337              20   205.348
# 4         1  2014        50   5.5099              20   220.396
# ...     ...   ...       ...      ...             ...       ...
# 7376      8  2019        50  47.9040              20  1916.160
# 7377      9  2019        50  49.1176              20  1964.704
# 7378     10  2019        50  50.8347              20  2033.388
# 7379     11  2019        50  51.7985              20  2071.940
# 7380     12  2019        50  51.6071              20  2064.284
#
# [7381 rows x 11 columns]

# %%
data.shape[0]
# Out:
# 7381

# %% [markdown]
# ## Thêm 1 dòng mới vào cuối bảng
# ### df.loc[cs]=[....]
# df.loc[df.shape[0]] = [....]

# %%
# Sai lầm
# data.loc[data.shape[0]]= ['Sài Gòn','3000','Dưa hấu','5','KG','10','6','2022','50.000','0','NaN']
# Chuẩn
data.loc[data.shape[0]]= ['Sài Gòn',3000,'Dưa hấu',5,'KG',10, 2022, 50,50.000,10,np.NaN]
display (data)
# data.info()
# Out:
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0     National Average     52            Rice - Retail       5         KG
# 1     National Average     52            Rice - Retail       5         KG
# 2     National Average     52            Rice - Retail       5         KG
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7377             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7378             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7379             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7381           Sài Gòn   3000                  Dưa hấu       5         KG
#
#       Tháng   Năm  Số lượng      Giá  Chiết khấu (%)      tổng
# 0         5  2013        50   4.4920              20   179.680
# 1         6  2013        50   4.5786              20   183.144
# 2        11  2013        50   4.7865              20   191.460
# 3        12  2013        50   5.1337              20   205.348
# 4         1  2014        50   5.5099              20   220.396
# ...     ...   ...       ...      ...             ...       ...
# 7377      9  2019        50  49.1176              20  1964.704
# 7378     10  2019        50  50.8347              20  2033.388
# 7379     11  2019        50  51.7985              20  2071.940
# 7380     12  2019        50  51.6071              20  2064.284
# 7381     10  2022        50  50.0000              10       NaN
#
# [7382 rows x 11 columns]

# %% [markdown]
# ### Thêm 1 dòng mới vào đầu bảng

# %%
# Thêm 1 dòng mới vào đầu bảng
data.loc[-1]= ['Hà Nội',3001,'Cốm làng Vòng',5,'KG',10,2022,20, 50.000,30,np.NaN]
# Update index của bảng
data.index = data.index + 1
# Sắp xếp lại bảng
data = data.sort_index()
display(data)
# data.info()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [75], in <cell line: 2>()
#       1 # Thêm 1 dòng mới vào đầu bảng
# ----> 2 data.loc[-1]= ['Hà Nội',3001,'Cốm làng Vòng',5,'KG',10,2022,20, 50.000,30,np.NaN]
#       3 # Update index của bảng
#       4 data.index = data.index + 1
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:716, in _LocationIndexer.__setitem__(self, key, value)
#     713 self._has_valid_setitem_indexer(key)
#     715 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 716 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1688, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1685 # align and set the values
#    1686 if take_split_path:
#    1687     # We have to operate column-wise
# -> 1688     self._setitem_with_indexer_split_path(indexer, value, name)
#    1689 else:
#    1690     self._setitem_single_block(indexer, value, name)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1770, in _iLocIndexer._setitem_with_indexer_split_path(self, indexer, value, name)
#    1767         self._setitem_single_column(ilocs[0], value, pi)
#    1769     else:
# -> 1770         raise ValueError(
#    1771             "Must have equal len keys and value "
#    1772             "when setting with an iterable"
#    1773         )
#    1775 else:
#    1776
#    1777     # scalar value
#    1778     for loc in ilocs:
#
# ValueError: Must have equal len keys and value when setting with an iterable

# %% [markdown]
# ### Thêm 1 dòng mới vào vị trí bất kỳ

# %%
#Cách 1: Swap giá trị các dòng
data.loc[-1] = data.loc[0]
data.loc[0] = ['Đà Nẵng',3002,'Mỳ Quảng',5,'Tô',10,2022,20, 100.000,10,np.NaN]
data.index = data.index +1
data = data.sort_index()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [73], in <cell line: 3>()
#       1 #Cách 1: Swap giá trị các dòng
#       2 data.loc[-1] = data.loc[0]
# ----> 3 data.loc[0] = ['Đà Nẵng',3002,'Mỳ Quảng',5,'Tô',10,2022,20, 100.000,10,np.NaN]
#       4 data.index = data.index +1
#       5 data = data.sort_index()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:716, in _LocationIndexer.__setitem__(self, key, value)
#     713 self._has_valid_setitem_indexer(key)
#     715 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 716 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1688, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1685 # align and set the values
#    1686 if take_split_path:
#    1687     # We have to operate column-wise
# -> 1688     self._setitem_with_indexer_split_path(indexer, value, name)
#    1689 else:
#    1690     self._setitem_single_block(indexer, value, name)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1770, in _iLocIndexer._setitem_with_indexer_split_path(self, indexer, value, name)
#    1767         self._setitem_single_column(ilocs[0], value, pi)
#    1769     else:
# -> 1770         raise ValueError(
#    1771             "Must have equal len keys and value "
#    1772             "when setting with an iterable"
#    1773         )
#    1775 else:
#    1776
#    1777     # scalar value
#    1778     for loc in ilocs:
#
# ValueError: Must have equal len keys and value when setting with an iterable

# %%
# Cách 2: Chèn thêm ở vị trí trung gian
# Chèn thêm dòng ở vị trí bất kỳ, ví dụ 0.5
data.loc[0.5]= ['Đà Nẫng',3002,'Mì quảng',5,'tô',10,9,2022,100.000,20,np.NaN]

#Sắp xếp lại các hàng theo đúng thứ tự từ nhỏ tới lớn và theo số tự nhiên
data = data.sort_index().reset_index(drop=True)

display(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [74], in <cell line: 3>()
#       1 # Cách 2: Chèn thêm ở vị trí trung gian
#       2 # Chèn thêm dòng ở vị trí bất kỳ, ví dụ 0.5
# ----> 3 data.loc[0.5]= ['Đà Nẫng',3002,'Mì quảng',5,'tô',10,9,2022,100.000,20,np.NaN]
#       5 #Sắp xếp lại các hàng theo đúng thứ tự từ nhỏ tới lớn và theo số tự nhiên
#       6 data = data.sort_index().reset_index(drop=True)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:716, in _LocationIndexer.__setitem__(self, key, value)
#     713 self._has_valid_setitem_indexer(key)
#     715 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 716 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1682, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1679     indexer, missing = convert_missing_indexer(indexer)
#    1681     if missing:
# -> 1682         self._setitem_with_indexer_missing(indexer, value)
#    1683         return
#    1685 # align and set the values
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1998, in _iLocIndexer._setitem_with_indexer_missing(self, indexer, value)
#    1995     if is_list_like_indexer(value):
#    1996         # must have conforming columns
#    1997         if len(value) != len(self.obj.columns):
# -> 1998             raise ValueError("cannot set a row with mismatched columns")
#    2000     value = Series(value, index=self.obj.columns, name=indexer)
#    2002 if not len(self.obj):
#    2003     # We will ignore the existing dtypes instead of using
#    2004     #  internals.concat logic
#
# ValueError: cannot set a row with mismatched columns

# %% [markdown]
# ## Xóa cột

# %% [markdown]
# ## Xóa cột sử dụng lệnh del
# ### del df['Tên cột cần xóa']

# %%
# Xóa cột sử dụng del
data2 = data
print('Data2 sau khi tạo')
display(data2)
# Xóa cột 'cột mới' (xóa ngay trên bảng gốc) -> Nguy hiểm, hạn chế dùng
del data2['tổng']
print('Data2 sau khi xóa')
display(data2)
print('Data sau khi xóa')
display(data)
# Out:
# Data2 sau khi tạo
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0               Hà Nội   3001            Cốm làng Vòng       5         KG
# 1              Đà Nẫng   3002                 Mì quảng       5         tô
# 2              Đà Nẵng   3002                 Mỳ Quảng       5         Tô
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7381             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7382             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7383             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7384           Sài Gòn   3000                  Dưa hấu       5         KG
#
#       Tháng   Năm  Số lượng       Giá  Chiết khấu (%)      tổng
# 0        10  2022        20   50.0000              30       NaN
# 1        10     9      2022  100.0000              20       NaN
# 2        10  2022        20  100.0000              10       NaN
# 3         5  2013        50    4.4920              20   179.680
# 4         6  2013        50    4.5786              20   183.144
# ...     ...   ...       ...       ...             ...       ...
# 7380      9  2019        50   49.1176              20  1964.704
# 7381     10  2019        50   50.8347              20  2033.388
# 7382     11  2019        50   51.7985              20  2071.940
# 7383     12  2019        50   51.6071              20  2064.284
# 7384     10  2022        50   50.0000              10       NaN
#
# [7385 rows x 11 columns]
# Data2 sau khi xóa
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0               Hà Nội   3001            Cốm làng Vòng       5         KG
# 1              Đà Nẫng   3002                 Mì quảng       5         tô
# 2              Đà Nẵng   3002                 Mỳ Quảng       5         Tô
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7381             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7382             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7383             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7384           Sài Gòn   3000                  Dưa hấu       5         KG
#
#       Tháng   Năm  Số lượng       Giá  Chiết khấu (%)
# 0        10  2022        20   50.0000              30
# 1        10     9      2022  100.0000              20
# 2        10  2022        20  100.0000              10
# 3         5  2013        50    4.4920              20
# 4         6  2013        50    4.5786              20
# ...     ...   ...       ...       ...             ...
# 7380      9  2019        50   49.1176              20
# 7381     10  2019        50   50.8347              20
# 7382     11  2019        50   51.7985              20
# 7383     12  2019        50   51.6071              20
# 7384     10  2022        50   50.0000              10
#
# [7385 rows x 10 columns]
# Data sau khi xóa
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0               Hà Nội   3001            Cốm làng Vòng       5         KG
# 1              Đà Nẫng   3002                 Mì quảng       5         tô
# 2              Đà Nẵng   3002                 Mỳ Quảng       5         Tô
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7381             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7382             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7383             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7384           Sài Gòn   3000                  Dưa hấu       5         KG
#
#       Tháng   Năm  Số lượng       Giá  Chiết khấu (%)
# 0        10  2022        20   50.0000              30
# 1        10     9      2022  100.0000              20
# 2        10  2022        20  100.0000              10
# 3         5  2013        50    4.4920              20
# 4         6  2013        50    4.5786              20
# ...     ...   ...       ...       ...             ...
# 7380      9  2019        50   49.1176              20
# 7381     10  2019        50   50.8347              20
# 7382     11  2019        50   51.7985              20
# 7383     12  2019        50   51.6071              20
# 7384     10  2022        50   50.0000              10
#
# [7385 rows x 10 columns]

# %% [markdown]
# ## Xóa cột sử dụng hàm pop()
# ### df.pop('Tên cột cần xóa')

# %%
# Xóa cột sử dụng pop()
data3 = data
print('Data3 sau khi tạo')
display(data3)
# Xóa cột 'cột mới' (xóa ngay trên bảng gốc) -> hạn chế dùng
data4 = data3.pop('Chiết khấu (%)') #-> kết quả là cột cần xóa
print('Data3 sau khi xóa')
display(data3)
print('Data sau khi xóa')
display(data)
print('Data4')
display(data4)
# Out:
# Data3 sau khi tạo
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0               Hà Nội   3001            Cốm làng Vòng       5         KG
# 1              Đà Nẫng   3002                 Mì quảng       5         tô
# 2              Đà Nẵng   3002                 Mỳ Quảng       5         Tô
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7381             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7382             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7383             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7384           Sài Gòn   3000                  Dưa hấu       5         KG
#
#       Tháng   Năm  Số lượng       Giá  Chiết khấu (%)      tổng
# 0        10  2022        20   50.0000              30       NaN
# 1        10     9      2022  100.0000              20       NaN
# 2        10  2022        20  100.0000              10       NaN
# 3         5  2013        50    4.4920              20   179.680
# 4         6  2013        50    4.5786              20   183.144
# ...     ...   ...       ...       ...             ...       ...
# 7380      9  2019        50   49.1176              20  1964.704
# 7381     10  2019        50   50.8347              20  2033.388
# 7382     11  2019        50   51.7985              20  2071.940
# 7383     12  2019        50   51.6071              20  2064.284
# 7384     10  2022        50   50.0000              10       NaN
#
# [7385 rows x 11 columns]
# Data3 sau khi xóa
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0               Hà Nội   3001            Cốm làng Vòng       5         KG
# 1              Đà Nẫng   3002                 Mì quảng       5         tô
# 2              Đà Nẵng   3002                 Mỳ Quảng       5         Tô
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7381             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7382             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7383             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7384           Sài Gòn   3000                  Dưa hấu       5         KG
#
#       Tháng   Năm  Số lượng       Giá      tổng
# 0        10  2022        20   50.0000       NaN
# 1        10     9      2022  100.0000       NaN
# 2        10  2022        20  100.0000       NaN
# 3         5  2013        50    4.4920   179.680
# 4         6  2013        50    4.5786   183.144
# ...     ...   ...       ...       ...       ...
# 7380      9  2019        50   49.1176  1964.704
# 7381     10  2019        50   50.8347  2033.388
# 7382     11  2019        50   51.7985  2071.940
# 7383     12  2019        50   51.6071  2064.284
# 7384     10  2022        50   50.0000       NaN
#
# [7385 rows x 10 columns]
# Data sau khi xóa
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0               Hà Nội   3001            Cốm làng Vòng       5         KG
# 1              Đà Nẫng   3002                 Mì quảng       5         tô
# 2              Đà Nẵng   3002                 Mỳ Quảng       5         Tô
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7381             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7382             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7383             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7384           Sài Gòn   3000                  Dưa hấu       5         KG
#
#       Tháng   Năm  Số lượng       Giá      tổng
# 0        10  2022        20   50.0000       NaN
# 1        10     9      2022  100.0000       NaN
# 2        10  2022        20  100.0000       NaN
# 3         5  2013        50    4.4920   179.680
# 4         6  2013        50    4.5786   183.144
# ...     ...   ...       ...       ...       ...
# 7380      9  2019        50   49.1176  1964.704
# 7381     10  2019        50   50.8347  2033.388
# 7382     11  2019        50   51.7985  2071.940
# 7383     12  2019        50   51.6071  2064.284
# 7384     10  2022        50   50.0000       NaN
#
# [7385 rows x 10 columns]
# Data4
# 0       30
# 1       20
# 2       10
# 3       20
# 4       20
#         ..
# 7380    20
# 7381    20
# 7382    20
# 7383    20
# 7384    10
# Name: Chiết khấu (%), Length: 7385, dtype: int64

# %% [markdown]
# ## Xóa cột sử dụng hàm drop()
# ### df.drop('Tên cột cần xóa’, axis=1, inplace=True/False)
# axis = 1 nghĩa là xóa cột
# inplace = True -> xóa cả dữ liệu gốc = del, pop()
# inplace = False -> dữ lại nguyên vẹn dữ liệu gốc (mặc định)

# %%
# Xóa cột sử dụng drop()
data4 = data
print('Data4')
display(data4)
# Xóa cột 'cột mới' (không xóa trực tiếp trên bảng gốc) -> nên dùng
data5 = data4.drop('Số lượng', axis=1, inplace=False)  #-> lấy kết quả trả về
# data5 = data4.drop('Số lượng', axis=1, inplace=True)  #-> không trả về kết quả mà cột bị xóa trực tiếp trên bảng gốc
print('Data4 sau khi xóa')
display(data4)
print('Data5')
display(data5)
print('Data gốc')
display(data)
# Out:
# Data4
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0               Hà Nội   3001            Cốm làng Vòng       5         KG
# 1              Đà Nẫng   3002                 Mì quảng       5         tô
# 2              Đà Nẵng   3002                 Mỳ Quảng       5         Tô
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7381             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7382             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7383             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7384           Sài Gòn   3000                  Dưa hấu       5         KG
#
#       Tháng   Năm  Số lượng       Giá      tổng
# 0        10  2022        20   50.0000       NaN
# 1        10     9      2022  100.0000       NaN
# 2        10  2022        20  100.0000       NaN
# 3         5  2013        50    4.4920   179.680
# 4         6  2013        50    4.5786   183.144
# ...     ...   ...       ...       ...       ...
# 7380      9  2019        50   49.1176  1964.704
# 7381     10  2019        50   50.8347  2033.388
# 7382     11  2019        50   51.7985  2071.940
# 7383     12  2019        50   51.6071  2064.284
# 7384     10  2022        50   50.0000       NaN
#
# [7385 rows x 10 columns]
# Data4 sau khi xóa
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0               Hà Nội   3001            Cốm làng Vòng       5         KG
# 1              Đà Nẫng   3002                 Mì quảng       5         tô
# 2              Đà Nẵng   3002                 Mỳ Quảng       5         Tô
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7381             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7382             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7383             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7384           Sài Gòn   3000                  Dưa hấu       5         KG
#
#       Tháng   Năm  Số lượng       Giá      tổng
# 0        10  2022        20   50.0000       NaN
# 1        10     9      2022  100.0000       NaN
# 2        10  2022        20  100.0000       NaN
# 3         5  2013        50    4.4920   179.680
# 4         6  2013        50    4.5786   183.144
# ...     ...   ...       ...       ...       ...
# 7380      9  2019        50   49.1176  1964.704
# 7381     10  2019        50   50.8347  2033.388
# 7382     11  2019        50   51.7985  2071.940
# 7383     12  2019        50   51.6071  2064.284
# 7384     10  2022        50   50.0000       NaN
#
# [7385 rows x 10 columns]
# Data5
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0               Hà Nội   3001            Cốm làng Vòng       5         KG
# 1              Đà Nẫng   3002                 Mì quảng       5         tô
# 2              Đà Nẵng   3002                 Mỳ Quảng       5         Tô
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7381             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7382             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7383             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7384           Sài Gòn   3000                  Dưa hấu       5         KG
#
#       Tháng   Năm       Giá      tổng
# 0        10  2022   50.0000       NaN
# 1        10     9  100.0000       NaN
# 2        10  2022  100.0000       NaN
# 3         5  2013    4.4920   179.680
# 4         6  2013    4.5786   183.144
# ...     ...   ...       ...       ...
# 7380      9  2019   49.1176  1964.704
# 7381     10  2019   50.8347  2033.388
# 7382     11  2019   51.7985  2071.940
# 7383     12  2019   51.6071  2064.284
# 7384     10  2022   50.0000       NaN
#
# [7385 rows x 9 columns]
# Data gốc
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0               Hà Nội   3001            Cốm làng Vòng       5         KG
# 1              Đà Nẫng   3002                 Mì quảng       5         tô
# 2              Đà Nẵng   3002                 Mỳ Quảng       5         Tô
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7381             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7382             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7383             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7384           Sài Gòn   3000                  Dưa hấu       5         KG
#
#       Tháng   Năm  Số lượng       Giá      tổng
# 0        10  2022        20   50.0000       NaN
# 1        10     9      2022  100.0000       NaN
# 2        10  2022        20  100.0000       NaN
# 3         5  2013        50    4.4920   179.680
# 4         6  2013        50    4.5786   183.144
# ...     ...   ...       ...       ...       ...
# 7380      9  2019        50   49.1176  1964.704
# 7381     10  2019        50   50.8347  2033.388
# 7382     11  2019        50   51.7985  2071.940
# 7383     12  2019        50   51.6071  2064.284
# 7384     10  2022        50   50.0000       NaN
#
# [7385 rows x 10 columns]

# %% [markdown]
# ## Xóa nhiều cột sử dụng hàm drop()
# ### df.drop(['Tên cột cần xóa1',…, 'Tên cột cần xóa n'], axis=1, inplace=True/False)

# %%
# Xóa cột 'cột mới' và cột 'số lượng'
data6 = data.drop(['Chiết khấu (%)', 'Số lượng'], axis=1)
print('Data6')
display(data6)
print('Data gốc')
display(data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [64], in <cell line: 2>()
#       1 # Xóa cột 'cột mới' và cột 'số lượng'
# ----> 2 data6 = data.drop(['Chiết khấu (%)', 'Số lượng'], axis=1)
#       3 print('Data6')
#       4 display(data6)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
#    4818     Drop specified labels from rows or columns.
#    4819
#    (...)
#    4952             weight  1.0     0.8
#    4953     """
# -> 4954     return super().drop(
#    4955         labels=labels,
#    4956         axis=axis,
#    4957         index=index,
#    4958         columns=columns,
#    4959         level=level,
#    4960         inplace=inplace,
#    4961         errors=errors,
#    4962     )
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265 for axis, labels in axes.items():
#    4266     if labels is not None:
# -> 4267         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4269 if inplace:
#    4270     self._update_inplace(obj)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:4311, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309         new_axis = axis.drop(labels, level=level, errors=errors)
#    4310     else:
# -> 4311         new_axis = axis.drop(labels, errors=errors)
#    4312     indexer = axis.get_indexer(new_axis)
#    4314 # Case for non-unique axis
#    4315 else:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:6644, in Index.drop(self, labels, errors)
#    6642 if mask.any():
#    6643     if errors != "ignore":
# -> 6644         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645     indexer = indexer[~mask]
#    6646 return self.delete(indexer)
#
# KeyError: "['Chiết khấu (%)'] not found in axis"

# %% [markdown]
# ## Xóa dòng sử dụng hàm drop()
# ### df.drop(cs, axis=0, inplace=True/False)
# axis = 0 -> xóa dòng
# cs là index của dòng đấy

# %%
#Xóa dòng cuối cùng
data6 = data.drop(data.shape[0]-1, axis=0)
print("Data6")
display(data6)
# Out:
# Data6
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0               Hà Nội   3001            Cốm làng Vòng       5         KG
# 1              Đà Nẫng   3002                 Mì quảng       5         tô
# 2              Đà Nẵng   3002                 Mỳ Quảng       5         Tô
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7379             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7381             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7382             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7383             Izmir    502  Cocoa (powder) - Retail       5         KG
#
#       Tháng   Năm  Số lượng       Giá      tổng
# 0        10  2022        20   50.0000       NaN
# 1        10     9      2022  100.0000       NaN
# 2        10  2022        20  100.0000       NaN
# 3         5  2013        50    4.4920   179.680
# 4         6  2013        50    4.5786   183.144
# ...     ...   ...       ...       ...       ...
# 7379      8  2019        50   47.9040  1916.160
# 7380      9  2019        50   49.1176  1964.704
# 7381     10  2019        50   50.8347  2033.388
# 7382     11  2019        50   51.7985  2071.940
# 7383     12  2019        50   51.6071  2064.284
#
# [7384 rows x 10 columns]

# %%
# Xóa dòng đầu tiên của bảng
data7 = data.drop(0, axis=0) #-> xóa đi và không reset lại index
display(data)
display(data7)
# data7.info()
# Out:
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0               Hà Nội   3001            Cốm làng Vòng       5         KG
# 1              Đà Nẫng   3002                 Mì quảng       5         tô
# 2              Đà Nẵng   3002                 Mỳ Quảng       5         Tô
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7381             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7382             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7383             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7384           Sài Gòn   3000                  Dưa hấu       5         KG
#
#       Tháng   Năm  Số lượng       Giá      tổng
# 0        10  2022        20   50.0000       NaN
# 1        10     9      2022  100.0000       NaN
# 2        10  2022        20  100.0000       NaN
# 3         5  2013        50    4.4920   179.680
# 4         6  2013        50    4.5786   183.144
# ...     ...   ...       ...       ...       ...
# 7380      9  2019        50   49.1176  1964.704
# 7381     10  2019        50   50.8347  2033.388
# 7382     11  2019        50   51.7985  2071.940
# 7383     12  2019        50   51.6071  2064.284
# 7384     10  2022        50   50.0000       NaN
#
# [7385 rows x 10 columns]
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 1              Đà Nẫng   3002                 Mì quảng       5         tô
# 2              Đà Nẵng   3002                 Mỳ Quảng       5         Tô
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# 5     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7381             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7382             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7383             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7384           Sài Gòn   3000                  Dưa hấu       5         KG
#
#       Tháng   Năm  Số lượng       Giá      tổng
# 1        10     9      2022  100.0000       NaN
# 2        10  2022        20  100.0000       NaN
# 3         5  2013        50    4.4920   179.680
# 4         6  2013        50    4.5786   183.144
# 5        11  2013        50    4.7865   191.460
# ...     ...   ...       ...       ...       ...
# 7380      9  2019        50   49.1176  1964.704
# 7381     10  2019        50   50.8347  2033.388
# 7382     11  2019        50   51.7985  2071.940
# 7383     12  2019        50   51.6071  2064.284
# 7384     10  2022        50   50.0000       NaN
#
# [7384 rows x 10 columns]

# %% [markdown]
# ## Xóa nhiều dòng sử dụng hàm drop()
# ### df.drop([cs1,…,csn], axis=0, inplace=True)

# %%
data
# Out:
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 0               Hà Nội   3001            Cốm làng Vòng       5         KG
# 1              Đà Nẫng   3002                 Mì quảng       5         tô
# 2              Đà Nẵng   3002                 Mỳ Quảng       5         Tô
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7381             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7382             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7383             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7384           Sài Gòn   3000                  Dưa hấu       5         KG
#
#       Tháng   Năm  Số lượng       Giá      tổng
# 0        10  2022        20   50.0000       NaN
# 1        10     9      2022  100.0000       NaN
# 2        10  2022        20  100.0000       NaN
# 3         5  2013        50    4.4920   179.680
# 4         6  2013        50    4.5786   183.144
# ...     ...   ...       ...       ...       ...
# 7380      9  2019        50   49.1176  1964.704
# 7381     10  2019        50   50.8347  2033.388
# 7382     11  2019        50   51.7985  2071.940
# 7383     12  2019        50   51.6071  2064.284
# 7384     10  2022        50   50.0000       NaN
#
# [7385 rows x 10 columns]

# %%
# Xóa dòng thứ Đà Nẵng, Hà Nội và Sài Gòn
data8 = data.drop([0,1,7383], axis=0)
data8
# Out:
#               Địa điểm  Mã SP                   Tên SP  Đơn vị Tên đơn vị  \
# 2              Đà Nẵng   3002                 Mỳ Quảng       5         Tô
# 3     National Average     52            Rice - Retail       5         KG
# 4     National Average     52            Rice - Retail       5         KG
# 5     National Average     52            Rice - Retail       5         KG
# 6     National Average     52            Rice - Retail       5         KG
# ...                ...    ...                      ...     ...        ...
# 7379             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7380             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7381             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7382             Izmir    502  Cocoa (powder) - Retail       5         KG
# 7384           Sài Gòn   3000                  Dưa hấu       5         KG
#
#       Tháng   Năm  Số lượng       Giá      tổng
# 2        10  2022        20  100.0000       NaN
# 3         5  2013        50    4.4920   179.680
# 4         6  2013        50    4.5786   183.144
# 5        11  2013        50    4.7865   191.460
# 6        12  2013        50    5.1337   205.348
# ...     ...   ...       ...       ...       ...
# 7379      8  2019        50   47.9040  1916.160
# 7380      9  2019        50   49.1176  1964.704
# 7381     10  2019        50   50.8347  2033.388
# 7382     11  2019        50   51.7985  2071.940
# 7384     10  2022        50   50.0000       NaN
#
# [7382 rows x 10 columns]

# %%
data.iloc[:5]
# Out:
#            Địa điểm  Mã SP         Tên SP  Đơn vị Tên đơn vị  Tháng   Năm  \
# 0            Hà Nội   3001  Cốm làng Vòng       5         KG     10  2022
# 1           Đà Nẫng   3002       Mì quảng       5         tô     10     9
# 2           Đà Nẵng   3002       Mỳ Quảng       5         Tô     10  2022
# 3  National Average     52  Rice - Retail       5         KG      5  2013
# 4  National Average     52  Rice - Retail       5         KG      6  2013
#
#    Số lượng       Giá     tổng
# 0        20   50.0000      NaN
# 1      2022  100.0000      NaN
# 2        20  100.0000      NaN
# 3        50    4.4920  179.680
# 4        50    4.5786  183.144

# %%
data.iloc[2.5:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [70], in <cell line: 1>()
# ----> 1 data.iloc[2.5:]
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1497, in _iLocIndexer._getitem_axis(self, key, axis)
#    1491     raise IndexError(
#    1492         "DataFrame indexer is not allowed for .iloc\n"
#    1493         "Consider using .loc for automatic alignment."
#    1494     )
#    1496 if isinstance(key, slice):
# -> 1497     return self._get_slice_axis(key, axis=axis)
#    1499 if is_iterator(key):
#    1500     key = list(key)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1532, in _iLocIndexer._get_slice_axis(self, slice_obj, axis)
#    1529     return obj.copy(deep=False)
#    1531 labels = obj._get_axis(axis)
# -> 1532 labels._validate_positional_slice(slice_obj)
#    1533 return self.obj._slice(slice_obj, axis=axis)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:4005, in Index._validate_positional_slice(self, key)
#    3999 @final
#    4000 def _validate_positional_slice(self, key: slice) -> None:
#    4001     """
#    4002     For positional indexing, a slice must have either int or None
#    4003     for each of start, stop, and step.
#    4004     """
# -> 4005     self._validate_indexer("positional", key.start, "iloc")
#    4006     self._validate_indexer("positional", key.stop, "iloc")
#    4007     self._validate_indexer("positional", key.step, "iloc")
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:6308, in Index._validate_indexer(self, form, key, kind)
#    6305 assert kind in ["getitem", "iloc"]
#    6307 if key is not None and not is_integer(key):
# -> 6308     raise self._invalid_indexer(form, key)
#
# TypeError: cannot do positional indexing on RangeIndex with these indexers [2.5] of type float

# %%
data.loc[:, 'Tên SP']
# Out:
#  0                 Cốm làng Vòng
#  1                      Mì quảng
#  2                      Mỳ Quảng
#  3                 Rice - Retail
#  4                 Rice - Retail
#                   ...
#  7381    Cocoa (powder) - Retail
#  7382    Cocoa (powder) - Retail
#  7383    Cocoa (powder) - Retail
#  7384                    Dưa hấu
# -1                 Cốm làng Vòng
# Name: Tên SP, Length: 7386, dtype: object

# %%
data.iloc[:, 2]
# Out:
#  0                 Cốm làng Vòng
#  1                      Mì quảng
#  2                      Mỳ Quảng
#  3                 Rice - Retail
#  4                 Rice - Retail
#                   ...
#  7381    Cocoa (powder) - Retail
#  7382    Cocoa (powder) - Retail
#  7383    Cocoa (powder) - Retail
#  7384                    Dưa hấu
# -1                 Cốm làng Vòng
# Name: Tên SP, Length: 7386, dtype: object

# %%
data.loc[:, ['ProductName', 'Place']]
# Out:
#                   ProductName             Place
# 0               Rice - Retail  National Average
# 1               Rice - Retail  National Average
# 2               Rice - Retail  National Average
# 3               Rice - Retail  National Average
# 4               Rice - Retail  National Average
# ...                       ...               ...
# 7376  Cocoa (powder) - Retail             Izmir
# 7377  Cocoa (powder) - Retail             Izmir
# 7378  Cocoa (powder) - Retail             Izmir
# 7379  Cocoa (powder) - Retail             Izmir
# 7380  Cocoa (powder) - Retail             Izmir
#
# [7381 rows x 2 columns]

# %%
data.iloc[:, [2, 0]]
# Out:
#                   ProductName             Place
# 0               Rice - Retail  National Average
# 1               Rice - Retail  National Average
# 2               Rice - Retail  National Average
# 3               Rice - Retail  National Average
# 4               Rice - Retail  National Average
# ...                       ...               ...
# 7376  Cocoa (powder) - Retail             Izmir
# 7377  Cocoa (powder) - Retail             Izmir
# 7378  Cocoa (powder) - Retail             Izmir
# 7379  Cocoa (powder) - Retail             Izmir
# 7380  Cocoa (powder) - Retail             Izmir
#
# [7381 rows x 2 columns]

# %%
display(data.head(10))
# Out:
#               Place  ProductId    ProductName  UmId UmName  Month  Year  \
# 0  National Average         52  Rice - Retail     5     KG      5  2013
# 1  National Average         52  Rice - Retail     5     KG      6  2013
# 2  National Average         52  Rice - Retail     5     KG     11  2013
# 3  National Average         52  Rice - Retail     5     KG     12  2013
# 4  National Average         52  Rice - Retail     5     KG      1  2014
# 5  National Average         52  Rice - Retail     5     KG      2  2014
# 6  National Average         52  Rice - Retail     5     KG      3  2014
# 7  National Average         52  Rice - Retail     5     KG      5  2014
# 8  National Average         52  Rice - Retail     5     KG      6  2014
# 9  National Average         52  Rice - Retail     5     KG      7  2014
#
#     Price
# 0  4.4920
# 1  4.5786
# 2  4.7865
# 3  5.1337
# 4  5.5099
# 5  5.8146
# 6  6.0014
# 7  6.3202
# 8  6.6019
# 9  6.6503

# %%
data.loc[:, 'ProductName':'UmName']
# Out:
#                   ProductName  UmId UmName
# 0               Rice - Retail     5     KG
# 1               Rice - Retail     5     KG
# 2               Rice - Retail     5     KG
# 3               Rice - Retail     5     KG
# 4               Rice - Retail     5     KG
# ...                       ...   ...    ...
# 7376  Cocoa (powder) - Retail     5     KG
# 7377  Cocoa (powder) - Retail     5     KG
# 7378  Cocoa (powder) - Retail     5     KG
# 7379  Cocoa (powder) - Retail     5     KG
# 7380  Cocoa (powder) - Retail     5     KG
#
# [7381 rows x 3 columns]

# %%
data.iloc[:, 1:5]
# Out:
#       ProductId              ProductName  UmId UmName
# 0            52            Rice - Retail     5     KG
# 1            52            Rice - Retail     5     KG
# 2            52            Rice - Retail     5     KG
# 3            52            Rice - Retail     5     KG
# 4            52            Rice - Retail     5     KG
# ...         ...                      ...   ...    ...
# 7376        502  Cocoa (powder) - Retail     5     KG
# 7377        502  Cocoa (powder) - Retail     5     KG
# 7378        502  Cocoa (powder) - Retail     5     KG
# 7379        502  Cocoa (powder) - Retail     5     KG
# 7380        502  Cocoa (powder) - Retail     5     KG
#
# [7381 rows x 4 columns]

# %%
display(data.head(15))
# Out:
#                Place  ProductId    ProductName  UmId UmName  Month  Year  \
# 0   National Average         52  Rice - Retail     5     KG      5  2013
# 1   National Average         52  Rice - Retail     5     KG      6  2013
# 2   National Average         52  Rice - Retail     5     KG     11  2013
# 3   National Average         52  Rice - Retail     5     KG     12  2013
# 4   National Average         52  Rice - Retail     5     KG      1  2014
# 5   National Average         52  Rice - Retail     5     KG      2  2014
# 6   National Average         52  Rice - Retail     5     KG      3  2014
# 7   National Average         52  Rice - Retail     5     KG      5  2014
# 8   National Average         52  Rice - Retail     5     KG      6  2014
# 9   National Average         52  Rice - Retail     5     KG      7  2014
# 10  National Average         52  Rice - Retail     5     KG      8  2014
# 11  National Average         52  Rice - Retail     5     KG      9  2014
# 12  National Average         52  Rice - Retail     5     KG     10  2014
# 13  National Average         52  Rice - Retail     5     KG     11  2014
# 14  National Average         52  Rice - Retail     5     KG     12  2014
#
#      Price
# 0   4.4920
# 1   4.5786
# 2   4.7865
# 3   5.1337
# 4   5.5099
# 5   5.8146
# 6   6.0014
# 7   6.3202
# 8   6.6019
# 9   6.6503
# 10  6.6806
# 11  6.6035
# 12  6.4960
# 13  6.6440
# 14  6.7240
